# %% [markdown]
# # Welcome to Lab: Simpson's Paradox 🔬
#
# Before this lab section, you learned about Simpson's Paradox and confounding variables in lecture.  This week, you will find Simpson's Paradox through analysis of a dataset in Python, and get some practice writing conditionals for pandas DataFrames!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Kim"
ca1_name = "Mia"
ca2_name = "Jai"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# Question of the Day (QOTD) to Ask Your Group: "Have you heard of ChatGPT?"
partner1_name = "Brian"
partner1_netid = "bmarty64"
partner1_chatgpt = "Yes"

partner2_name = "Toby"
partner2_netid = "tgort2"
partner2_chatgpt = "Yes"

partner3_name = "Kasra"
partner3_netid = "kvaki2"
partner3_chatgpt= "Yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: The GPA Dataset
#
# Many of you have likely come across one of the GPA visualizations found at https://waf.cs.illinois.edu/discovery/gpa/, either out of
# curiosity or the need to investigate a mysterious GenEd class you signed up for.
#
# Regardless, these visualizations are built on the **GPA Dataset** of UIUC students across all course subjects. Today, you're going to do some analysis and discover a case of Simpson's Paradox within data taken from UIUC courses!

# %% [markdown]
# ## Load the GPA Dataset
#
# The most recent version of the "GPA Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/gpa.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
import pandas as pd
df= pd.read_csv("https://waf.cs.illinois.edu/discovery/gpa.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 1      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 2      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 3      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 4      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 64043  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 64044  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 64045  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 64046  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 64047  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C+  C  C-  D+  D  D-  F  W  \
# 0            LCD   6  13   0  ...   0  3   0   1  1   0  0  0
# 1            DIS   0  11   5  ...   1  0   1   1  0   0  0  0
# 2            DIS   0  10   7  ...   0  0   0   0  0   0  2  0
# 3            DIS  17   8   1  ...   0  0   0   0  0   0  0  0
# 4             OD   0   8   4  ...   1  0   0   0  0   1  3  1
# ...          ...  ..  ..  ..  ...  .. ..  ..  .. ..  .. .. ..
# 64043        LEC   5  10   2  ...   0  1   3   0  0   0  2  1
# 64044        LEC   4  12   8  ...   0  0   0   0  0   0  0  0
# 64045        LEC   0   1   3  ...   5  1   1   0  2   0  1  0
# 64046        LCD   1   2   2  ...   3  3   2   0  0   1  1  0
# 64047        LEC   5   8   9  ...   0  4   0   0  1   0  2  0
#
#              Primary Instructor  Students
# 0                   Lee, Sang S        29
# 1                 Zheng, Reanne        25
# 2                 Zheng, Reanne        27
# 3      Rosado-Torres, Alexander        28
# 4                      Wang, Yu        21
# ...                         ...       ...
# 64043        Stepanov, Alexei G        31
# 64044              Unger, David        28
# 64045         Morgan, William T        28
# 64046  Ott-Monsivais, Stephanie        21
# 64047          Keane, Richard D        39
#
# [64048 rows x 23 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df) == 64048 ), "This is not the GPA dataset you're looking for"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Data Cleaning: An Additional Column
#
# The GPA dataset contains raw GPA data and is not the easiest to work with if we want to analyze intricacies such as the average GPA or passing rate.  Luckily, DataFrames are modifiable, so we can **add more columns** based on what questions we want to answer.
#
# The process of modifying a dataset via deletion (cleaning up empty/unwanted values) or addition (adding new columns) is often called **data cleaning**. This is an important concept in Data Science, because you won't always receive your data in the perfect format for your purposes.
#
# With the GPA dataset, we want to investigate one innocent question posed by a theoretical incoming student:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# To do this, we'll need to first perform some modifications on our loaded DataFrame, `df`. Specifically, we will need to create:
# - An `A_Grade` column, containing the total number of students receiving an A+, A, or A- in every course

# %% [markdown]
# ### Puzzle 1.1: Creating an `A_Grade` Column
#
# Create the new column `A_Grade` that stores the total number of "A"s given in every course.
#
# - We consider an "A" to be any type of A, in other words "A+", "A", or an "A-" are all included.
# - In our `df`, the number of students recieving a particular grade in a course is found in the `df['Grade']` column. For example, `df['A']` contains the number of students who recieved an A

# %%
df['A_Grade'] = df['A'] + df['A+'] + df['A-'] 
df['A_Grade']
# Out:
# 0        19
# 1        16
# 2        17
# 3        26
# 4        12
#          ..
# 64043    17
# 64044    24
# 64045     4
# 64046     5
# 64047    22
# Name: A_Grade, Length: 64048, dtype: int64

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('A_Grade' in df), "Make sure you've named the A_Grade column properly and added it to the dataframe"
assert(df['A_Grade'].sum() == 2096341), "Double check the values of your A_Grade column"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# # Part 1: Working with the GPA Dataset
# Now that we have that extra column set up, we can perform basic mathematical analysis on the GPA Dataset to get insight towards our question:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# Should be simple, right? Let's just see which subject, STAT or CS, has a greater percentage of A grades .

# %% [markdown]
# ### Puzzle 1.2: Subject DataFrames
#
# Select only the rows of the GPA dataset `df` with a `Subject` of `STAT`. Assign these rows to a new DataFrame, `df_STAT`.
# - Make sure your result only contains STAT courses!

# %%
df_STAT = df[df.Subject == 'STAT']
df_STAT
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 2172   2022  Spring  2022-sp    STAT     100                     Statistics
# 2173   2022  Spring  2022-sp    STAT     100                     Statistics
# 2174   2022  Spring  2022-sp    STAT     100                     Statistics
# 2175   2022  Spring  2022-sp    STAT     107         Data Science Discovery
# 2176   2022  Spring  2022-sp    STAT     200           Statistical Analysis
# ...     ...     ...      ...     ...     ...                            ...
# 64040  2010  Summer  2010-su    STAT     100                     Statistics
# 64041  2010  Summer  2010-su    STAT     100                     Statistics
# 64042  2010  Summer  2010-su    STAT     400   Statistics and Probability I
# 64043  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 64044  2010  Summer  2010-su    STAT     440    Statistical Data Management
#
#       Sched Type   A+    A  A-  ...   C  C-  D+   D  D-   F  W  \
# 2172         LEC  186  106  55  ...  30  10  14  10   8  11  2
# 2173         ONL  178  126  72  ...  24  19  11  15  12  16  2
# 2174         ONL   19   21   4  ...   0   3   0   2   2   9  1
# 2175         LEC    9  125  24  ...   5   2   6   2   1  10  2
# 2176         ONL   57  131  41  ...  13   4   2   0   2   9  2
# ...          ...  ...  ...  ..  ...  ..  ..  ..  ..  ..  .. ..
# 64040        LCD    1   13   3  ...   2   2   3   1   1   1  0
# 64041        LCD    0   14   3  ...   3   0   0   1   0   3  1
# 64042        LEC    4   15   7  ...   2   2   0   1   0   3  1
# 64043        LEC    5   10   2  ...   1   3   0   0   0   2  1
# 64044        LEC    4   12   8  ...   0   0   0   0   0   0  0
#
#        Primary Instructor  Students  A_Grade
# 2172    Flanagan, Karle A       582      347
# 2173    Flanagan, Karle A       663      376
# 2174     Reger, William J        84       44
# 2175    Flanagan, Karle A       230      158
# 2176     Fireman, Ellen S       350      229
# ...                   ...       ...      ...
# 64040  Hirtz, Nathaniel R        39       17
# 64041    Dalpiaz, David M        28       17
# 64042      Monrad, Ditlev        47       26
# 64043  Stepanov, Alexei G        31       17
# 64044        Unger, David        28       24
#
# [935 rows x 24 columns]

# %% [markdown]
# Select only the rows of the GPA dataset `df` with a `Subject` of `CS`. Assign these rows to a new dataframe, `df_CS`.
# - Make sure your result only contains CS courses!

# %%
df_CS = df[df.Subject == 'CS']
df_CS
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 712    2022  Spring  2022-sp      CS     101   Intro Computing: Engrg & Sci
# 713    2022  Spring  2022-sp      CS     105      Intro Computing: Non-Tech
# 714    2022  Spring  2022-sp      CS     105      Intro Computing: Non-Tech
# 715    2022  Spring  2022-sp      CS     124    Intro to Computer Science I
# 716    2022  Spring  2022-sp      CS     126         Software Design Studio
# ...     ...     ...      ...     ...     ...                            ...
# 63924  2010  Summer  2010-su      CS     101   Intro Computing: Engrg & Sci
# 63925  2010  Summer  2010-su      CS     225                Data Structures
# 63926  2010  Summer  2010-su      CS     373          Theory of Computation
# 63927  2010  Summer  2010-su      CS     421  Progrmg Languages & Compilers
# 63928  2010  Summer  2010-su      CS     598  Object-Oriented Prog & Design
#
#       Sched Type   A+    A  A-  ...   C  C-  D+   D  D-   F  W  \
# 712          OLC  155  340  55  ...   3   6   4   6   0  17  1
# 713          OLC   12   62  17  ...  16  14   3   4   4   9  2
# 714          OLC   28  101  26  ...  19  20   4   9   2  10  3
# 715          OLC   70  314  43  ...   9   9   0  18   0  28  4
# 716          LCD   47  105  25  ...   1   0   1   3   2   5  0
# ...          ...  ...  ...  ..  ...  ..  ..  ..  ..  ..  .. ..
# 63924        LBD    4    6   2  ...   0   1   0   0   0   0  0
# 63925        LBD    1    5   1  ...   3   1   0   2   0   1  0
# 63926        LEC    5    1   5  ...   0   2   0   2   0   1  1
# 63927        LCD    2    5   5  ...   1   4   0   4   0   0  1
# 63928        ONL    3   22   0  ...   0   0   0   0   0   0  0
#
#         Primary Instructor  Students  A_Grade
# 712          Davis, Neal E       642      550
# 713          Zilles, Craig       193       91
# 714          Zilles, Craig       308      155
# 715    Challen, Geoffrey W       578      427
# 716     Woodley, Michael J       203      177
# ...                    ...       ...      ...
# 63924    Gambill, Thomas N        21       12
# 63925        Earls, John C        21        7
# 63926         Kumar, Viraj        26       11
# 63927       Hafiz, Munawar        30       12
# 63928     Johnson, Ralph E        30       25
#
# [2066 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.3: Comparing Overall Percentages
#
# With our two new dataframes of STAT and CS courses, use the following code cell to determine the **percentage** of A grades recieved in STAT and CS courses, storing them as variables `stat_a` and `cs_a` respectively.
#
# Print statements have been provided to show the values you calculate.
#
# As you work, remember:
# - To find the **% of As**, divide the total number of `A_Grade`s by the total number of `Students` ($\space \frac{A \space Grades}{Students} \space$)
# - The `A_Grade` column you made earlier, and the `Students` column containing the total number of students in each course.
# - The syntax `sum(df['column_name'])` can be used to add up the values of all rows in a particular column of a DataFrame.

# %%
stat_a = sum(df_STAT['A_Grade']) / (sum(df_STAT['Students']))
print(f'Overall % of As in STAT is: {stat_a}')

cs_a = sum(df_CS['A_Grade']) / (sum(df_CS['Students']))
print(f'Overall % of As in CS is: {cs_a}')
# Out:
# Overall % of As in STAT is: 0.6051620045305918
# Overall % of As in CS is: 0.596793417279641

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert(math.isclose(stat_a, 0.6051620045305918)), "The overall percentage of A grades recieved in STAT courses does not appear to have been correctly calculated"
assert(math.isclose(cs_a, 0.596793417279641)), "The overall percentage of A grades recieved in CS courses does not appear to have been correctly calculated"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Good Comparison?
# **Q: What conclusion can you take from the overall percentages found above when asking the original question:**
# - *Is it easier to get an A in STAT or CS courses at UIUC?*

# %% [markdown]
# It is easier to get an A in STAT because the percentage of As in STAT is higher than CS

# %% [markdown]
# **Q: Given what you've learned about experimental design, what are some reasons (specific to this dataset) you may not trust this conclusion? If you would trust it, explain why.**

# %% [markdown]
# I may not trust this conclusion as a percentage because these two percentages are comparing four different variables of A's and total students in both STAT/CS. I think this could be an example of Simpsons Paradox.

# %% [markdown]
# ## An Extra Consideration
#
# If you look at the `Year` column of our GPA dataset, you might notice that we have some old data in our set - all the way back to **2010**! This means we aren't really answering our question from the perspective of a student now.
#
# If we want to know if it is easier to **currently** get an A in a STAT or CS course, we should control for the **date** of the data by looking at more **recent years** specifically.

# %% [markdown]
# ### Puzzle 1.4: More DataFrames
#
# Using the code cells below, define four new DataFrames by selecting from rows of our previously created `df_CS` and `df_STAT`.
#
# - `df_cs_recent`: all `CS` course data in *recent years* ($\space \geq 2021 \space$)
# - `df_stat_recent`: all `STAT` course data in *recent years* ($\space \geq 2021 \space$)
# - `df_cs_old`: all other, older `CS` course data ($\space < 2021 \space$)
# - `df_stat_old`: all other, older `STAT` course data ($\space < 2021 \space$)
#
# Define *recent years* as **any year after and including 2021**, and older years as any year before 2021.
#
# Feel free to use conditionals OR the `.isin()` syntax you learned in the last lab.

# %%
df_stat_recent = df_STAT[df_STAT['YearTerm'] >= '2021']
df_stat_recent
# Out:
#       Year    Term YearTerm Subject  Number                   Course Title  \
# 2172  2022  Spring  2022-sp    STAT     100                     Statistics
# 2173  2022  Spring  2022-sp    STAT     100                     Statistics
# 2174  2022  Spring  2022-sp    STAT     100                     Statistics
# 2175  2022  Spring  2022-sp    STAT     107         Data Science Discovery
# 2176  2022  Spring  2022-sp    STAT     200           Statistical Analysis
# ...    ...     ...      ...     ...     ...                            ...
# 7541  2021  Summer  2021-su    STAT     400   Statistics and Probability I
# 7542  2021  Summer  2021-su    STAT     410  Statistics and Probability II
# 7543  2021  Summer  2021-su    STAT     420      Statistical Modeling in R
# 7544  2021  Summer  2021-su    STAT     420  Methods of Applied Statistics
# 7545  2021  Summer  2021-su    STAT     425  Applied Regression and Design
#
#      Sched Type   A+    A  A-  ...   C  C-  D+   D  D-   F  W  \
# 2172        LEC  186  106  55  ...  30  10  14  10   8  11  2
# 2173        ONL  178  126  72  ...  24  19  11  15  12  16  2
# 2174        ONL   19   21   4  ...   0   3   0   2   2   9  1
# 2175        LEC    9  125  24  ...   5   2   6   2   1  10  2
# 2176        ONL   57  131  41  ...  13   4   2   0   2   9  2
# ...         ...  ...  ...  ..  ...  ..  ..  ..  ..  ..  .. ..
# 7541        OLC   11   22   6  ...   4   3   2   1   0   7  2
# 7542        ONL    8   14   4  ...   3   0   0   3   0   4  2
# 7543        ONL  101   94  15  ...   1   0   0   0   0   2  4
# 7544        ONL    5    8   1  ...   2   0   0   0   0   1  0
# 7545        ONL   13   13   8  ...   0   1   0   0   0   5  0
#
#           Primary Instructor  Students  A_Grade
# 2172       Flanagan, Karle A       582      347
# 2173       Flanagan, Karle A       663      376
# 2174        Reger, William J        84       44
# 2175       Flanagan, Karle A       230      158
# 2176        Fireman, Ellen S       350      229
# ...                      ...       ...      ...
# 7541        Nguyen, Ha Khanh        84       39
# 7542      Stepanov, Alexey G        56       26
# 7543            Unger, David       227      210
# 7544            Unger, David        22       14
# 7545  Bravo De Guenni, Lelys        45       34
#
# [137 rows x 24 columns]

# %%
df_cs_recent = df_CS[df_CS['YearTerm'] >= '2021']
df_cs_recent
# Out:
#       Year    Term YearTerm Subject  Number                   Course Title  \
# 712   2022  Spring  2022-sp      CS     101   Intro Computing: Engrg & Sci
# 713   2022  Spring  2022-sp      CS     105      Intro Computing: Non-Tech
# 714   2022  Spring  2022-sp      CS     105      Intro Computing: Non-Tech
# 715   2022  Spring  2022-sp      CS     124    Intro to Computer Science I
# 716   2022  Spring  2022-sp      CS     126         Software Design Studio
# ...    ...     ...      ...     ...     ...                            ...
# 7393  2021  Summer  2021-su      CS     416             Data Visualization
# 7394  2021  Summer  2021-su      CS     421  Progrmg Languages & Compilers
# 7395  2021  Summer  2021-su      CS     421  Progrmg Languages & Compilers
# 7396  2021  Summer  2021-su      CS     598                 Cloud Capstone
# 7397  2021  Summer  2021-su      CS     598           Data Mining Capstone
#
#      Sched Type   A+    A  A-  ...   C  C-  D+   D  D-   F  W  \
# 712         OLC  155  340  55  ...   3   6   4   6   0  17  1
# 713         OLC   12   62  17  ...  16  14   3   4   4   9  2
# 714         OLC   28  101  26  ...  19  20   4   9   2  10  3
# 715         OLC   70  314  43  ...   9   9   0  18   0  28  4
# 716         LCD   47  105  25  ...   1   0   1   3   2   5  0
# ...         ...  ...  ...  ..  ...  ..  ..  ..  ..  ..  .. ..
# 7393        ONL  265  113  25  ...   0   0   0   0   0   3  8
# 7394        ONL   50   20   5  ...   2   0   0   2   0   4  2
# 7395        OLC   17    8   6  ...   4   0   0   6   0   5  3
# 7396        ONL   55   15   3  ...   1   0   0   1   0   0  0
# 7397        ONL   11   16   1  ...   0   0   0   0   0   0  0
#
#        Primary Instructor  Students  A_Grade
# 712         Davis, Neal E       642      550
# 713         Zilles, Craig       193       91
# 714         Zilles, Craig       308      155
# 715   Challen, Geoffrey W       578      427
# 716    Woodley, Michael J       203      177
# ...                   ...       ...      ...
# 7393         Hart, John C       432      403
# 7394    Beckman, Mattox A        92       75
# 7395    Beckman, Mattox A        62       31
# 7396        Farivar, Reza        75       73
# 7397        Farivar, Reza        29       28
#
# [270 rows x 24 columns]

# %%
df_stat_old = df_STAT[df_STAT['YearTerm'] < '2021']
df_stat_old
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 9790   2020    Fall  2020-fa    STAT     100                     Statistics
# 9791   2020    Fall  2020-fa    STAT     107         Data Science Discovery
# 9792   2020    Fall  2020-fa    STAT     200           Statistical Analysis
# 9793   2020    Fall  2020-fa    STAT     200           Statistical Analysis
# 9794   2020    Fall  2020-fa    STAT     212                  Biostatistics
# ...     ...     ...      ...     ...     ...                            ...
# 64040  2010  Summer  2010-su    STAT     100                     Statistics
# 64041  2010  Summer  2010-su    STAT     100                     Statistics
# 64042  2010  Summer  2010-su    STAT     400   Statistics and Probability I
# 64043  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 64044  2010  Summer  2010-su    STAT     440    Statistical Data Management
#
#       Sched Type   A+    A   A-  ...   C  C-  D+   D  D-   F  W  \
# 9790         ONL  402  283  159  ...  43  34  15  15   5  35  0
# 9791         OLC   22   86   13  ...   4   4   1   0   0   5  0
# 9792         ONL   26    1    3  ...   1   0   3   1   0   1  0
# 9793         ONL   60  112   39  ...   9   6   1   4   0   1  0
# 9794         ONL   50   80   39  ...   4   4   1   2   1   1  0
# ...          ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  .. ..
# 64040        LCD    1   13    3  ...   2   2   3   1   1   1  0
# 64041        LCD    0   14    3  ...   3   0   0   1   0   3  1
# 64042        LEC    4   15    7  ...   2   2   0   1   0   3  1
# 64043        LEC    5   10    2  ...   1   3   0   0   0   2  1
# 64044        LEC    4   12    8  ...   0   0   0   0   0   0  0
#
#         Primary Instructor  Students  A_Grade
# 9790     Flanagan, Karle A      1340      844
# 9791      Nguyen, Ha Khanh       163      121
# 9792   Ellison, Victoria M        40       30
# 9793      Fireman, Ellen S       319      211
# 9794      Findley, Kelly P       242      169
# ...                    ...       ...      ...
# 64040   Hirtz, Nathaniel R        39       17
# 64041     Dalpiaz, David M        28       17
# 64042       Monrad, Ditlev        47       26
# 64043   Stepanov, Alexei G        31       17
# 64044         Unger, David        28       24
#
# [798 rows x 24 columns]

# %%
df_cs_old = df_CS[df_CS['YearTerm'] < '2021']
df_cs_old
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 8276   2020    Fall  2020-fa      CS     100           Freshman Orientation
# 8277   2020    Fall  2020-fa      CS     100           Freshman Orientation
# 8278   2020    Fall  2020-fa      CS     101   Intro Computing: Engrg & Sci
# 8279   2020    Fall  2020-fa      CS     105      Intro Computing: Non-Tech
# 8280   2020    Fall  2020-fa      CS     105      Intro Computing: Non-Tech
# ...     ...     ...      ...     ...     ...                            ...
# 63924  2010  Summer  2010-su      CS     101   Intro Computing: Engrg & Sci
# 63925  2010  Summer  2010-su      CS     225                Data Structures
# 63926  2010  Summer  2010-su      CS     373          Theory of Computation
# 63927  2010  Summer  2010-su      CS     421  Progrmg Languages & Compilers
# 63928  2010  Summer  2010-su      CS     598  Object-Oriented Prog & Design
#
#       Sched Type   A+    A  A-  ...   C  C-  D+  D  D-   F  W  \
# 8276         ONL    0  267   2  ...   0   0   0  1   0   1  0
# 8277         OLC    0   17   1  ...   0   0   1  0   0   1  0
# 8278         OLC  181  191  19  ...   2   5   1  1   0   5  0
# 8279         OLC   31  105  72  ...  20  17   3  2   2  14  0
# 8280         OLC   20   45  27  ...   4   3   3  2   1   6  0
# ...          ...  ...  ...  ..  ...  ..  ..  .. ..  ..  .. ..
# 63924        LBD    4    6   2  ...   0   1   0  0   0   0  0
# 63925        LBD    1    5   1  ...   3   1   0  2   0   1  0
# 63926        LEC    5    1   5  ...   0   2   0  2   0   1  1
# 63927        LCD    2    5   5  ...   1   4   0  4   0   0  1
# 63928        ONL    3   22   0  ...   0   0   0  0   0   0  0
#
#        Primary Instructor  Students  A_Grade
# 8276         Gunter, Elsa       277      269
# 8277         Gunter, Elsa        22       18
# 8278        Davis, Neal E       434      391
# 8279        Zilles, Craig       420      208
# 8280        Zilles, Craig       174       92
# ...                   ...       ...      ...
# 63924   Gambill, Thomas N        21       12
# 63925       Earls, John C        21        7
# 63926        Kumar, Viraj        26       11
# 63927      Hafiz, Munawar        30       12
# 63928    Johnson, Ralph E        30       25
#
# [1796 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_stat_recent' in vars() ), "Make certain to name the recent STAT courses df_stat_recent."
assert( 'df_cs_recent' in vars() ), "Make certain to name the recent CS courses df_cs_recent."
assert( 'df_stat_old' in vars() ), "Make certain to name the old STAT courses df_stat_old."
assert( 'df_cs_old' in vars() ), "Make certain to name the old CS courses df_cs_old."

assert( len(df_stat_recent[df_stat_recent.Year < 2021] ) == 0 ), "Make sure only years after and including 2021 are in the df_stat_recent dataframe."
assert( len(df_cs_recent[df_cs_recent.Year < 2021] ) == 0 ), "Make sure only years after and including 2021 are in the df_cs_recent dataframe."
assert( len(df_stat_old[df_stat_old.Year >= 2021] ) == 0 ), "Make sure only years before 2021 are in the df_stat_old dataframe."
assert( len(df_cs_old[df_cs_old.Year >= 2021] ) == 0 ), "Make sure only years before 2021 are in the df_cs_old dataframe."

assert( len(df[ df.index.isin(df_stat_recent.index) & df.index.isin(df_stat_old.index) ]) == 0 ), "Check for duplicate values in your df_stat_recent and df_stat_old dataframes."
assert( len(df[ df.index.isin(df_cs_recent.index) & df.index.isin(df_cs_old.index) ]) == 0 ), "Check for duplicate values in your df_cs_recent and df_cs_old dataframes."
assert( len(df_cs_old) + len(df_cs_recent) == len(df_CS) ), "You're excluding some rows from df_cs_old or df_cs_young. Please double check your conditionals."
assert( len(df_stat_old) + len(df_stat_recent) == len(df_STAT) ), "You're excluding some rows from df_stat_old or df_stat_recent. Please double check your conditionals."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.5: New Analysis
# Now that we've got all the DataFrames setup with GPA data of the `CS` and `STAT` courses separated by recency (2021 or newer being 'recent'), we can do more in-depth analysis to investigate our question.
#
# In the following code cells, **calculate the percentages** described by the comment in the cell. Your answer should always be a **decimal between 0 and 1**.
#
# Just like Puzzle 1.2, remember:
# - To find the % of As, divide the total number of students by the total number of As
# - The `A_Grade` column you made earlier, and the `Students` column containing the total number of students in each course.
# - The syntax `sum(df['column_name'])` can be used to add up the values of all rows in a particular column of a DataFrame.

# %%
# Percentage of As received in CS in recent years
cs_recent_a = sum(df_cs_recent['A_Grade']) / (sum(df_cs_recent['Students']))
print(f'Percentage of As received in CS in recent years: {cs_recent_a}')
# Out:
# Percentage of As received in CS in recent years: 0.7052750783492665

# %%
# Percentage of As received in STAT in recent years
stat_recent_a = sum(df_stat_recent['A_Grade']) / (sum(df_stat_recent['Students']))
print(f'Percentage of As received in STAT in recent years: {stat_recent_a}')
# Out:
# Percentage of As received in STAT in recent years: 0.6488539077602872

# %%
# percentage of As received in CS in older years
cs_old_a = sum(df_cs_old['A_Grade']) / (sum(df_cs_old['Students']))
print(f'Percentage of As received in CS in older years: {cs_old_a}')
# Out:
# Percentage of As received in CS in older years: 0.5714531786360225

# %%
# percentage of As received in STAT in older years
stat_old_a = sum(df_stat_old['A_Grade']) / (sum(df_stat_old['Students']))
print(f'Percentage of As received in STAT in older years: {stat_old_a}')
# Out:
# Percentage of As received in STAT in older years: 0.5975443876015648

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(math.isclose(cs_recent_a,  0.7052750783492665)), "The overall percentage of A grades recieved in STAT courses recently does not appear to have been correctly calculated"
assert(math.isclose(stat_recent_a, 0.6488539077602872)), "The overall percentage of A grades recieved in CS courses recently does not appear to have been correctly calculated"

assert(math.isclose(cs_old_a, 0.5714531786360225)), "The overall percentage of A grades recieved in STAT courses in older years does not appear to have been correctly calculated"
assert(math.isclose(stat_old_a, 0.5975443876015648)), "The overall percentage of A grades recieved in CS courses in older years does not appear to have been correctly calculated"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Observe the Results
# **Run the following cell** to format all of your answers as a DataFrame.
#
# Keep in mind that "Older" means data from courses **before 2021**, and "Recent" means courses held **during or after 2021**.

# %%
pd.DataFrame([
  {'Older % of A': cs_old_a, 'Recent % of A': cs_recent_a, 'Overall % of A': cs_a},
  {'Older % of A': stat_old_a, 'Recent % of A': stat_recent_a, 'Overall % of A': stat_a}
], index=['CS', 'STAT'])
# Out:
#       Older % of A  Recent % of A  Overall % of A
# CS        0.571453       0.705275        0.596793
# STAT      0.597544       0.648854        0.605162

# %% [markdown]
# Notice that when observing the overall % of A grades received, you may think `STAT` and `CS` are equally difficult to get an `A_Grade` in. But in the sub-group of the courses held in years of **2021 and later**, we see that `CS` actually has a higher `A_Grade` rate!
#
# This is **Simpson's Paradox**: a pattern within a population can appear, disappear, or reverse when you look at subpopulations.
#
# In more formal terms, Simpson's Paradox can cause you to observe a pattern reverse when you look at the overall group statistics versus statistics of groups post-stratification. In this case we are stratifying by time.

# %% [markdown]
# ### Analysis: Reflecting on New Observations

# %% [markdown]
# You should see the pattern reverse when you look at the overall A grade percentages vs. the percentages stratified to account for recency. This is called **Simpson's Paradox**: a pattern within a population can appear, disappear, or reverse when you look at subpopulations.
#
# Now think about how would you now respond differently to the incoming student's question:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# **Q: Which comparison of percentages do you trust more and why? Are there any other potential confounding variables when answering this question that could be investigated further? Respond with at least three full sentences.**

# %% [markdown]
# I trust the comparison of percentages of recent percentages more because the data is more relevant to the person investigating. I think that another confounder could possibly be the total number of students in both subjects or the undergraduate/graduate level courses. I think it is easier to get an A in CS courses in recent years, as the percentages of the A's went up over 10%! This shows to me that the CS coursework must have changed in some way to lead to this percentage.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Revisiting the Hello Dataset
#
# Enough about GPA (for now). Two weeks ago, you created a series of questions that made up the **Hello Dataset** and completed the survey by answering all of the questions made by students in DISCOVERY.
#
# Now, we will load this dataset again and briefly answer a few questions with data about YOU!

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df_hello`:

# %%
df_hello = pd.read_csv('https://waf.cs.illinois.edu/discovery/hello-sp23.csv')
df_hello
# Out:
#            Name   Section  Are you a "Type A" or "Type B" personality?  \
# 0    Prof Karle       AL1        Type B (patient, flexible, laid-back)
# 1     Prof Wade       AL1  Type A (ambitious, competitive, aggressive)
# 2         Harsh       AYB  Type A (ambitious, competitive, aggressive)
# 3       Norman        AYO        Type B (patient, flexible, laid-back)
# 4       Christ`       AYM  Type A (ambitious, competitive, aggressive)
# ..          ...       ...                                          ...
# 368      Maryam       AYC  Type A (ambitious, competitive, aggressive)
# 369        Nick       AYB  Type A (ambitious, competitive, aggressive)
# 370       Bowei       AYE        Type B (patient, flexible, laid-back)
# 371        Sean       AYF        Type B (patient, flexible, laid-back)
# 372   TA Yiming  AYO, AYQ  Type A (ambitious, competitive, aggressive)
#
#     Are you a morning person? Are you an international student?  \
# 0                          No                                No
# 1                          No                                No
# 2                         Yes                               Yes
# 3                          No                               Yes
# 4                         Yes                                No
# ..                        ...                               ...
# 368                        No                                No
# 369                        No                               Yes
# 370                        No                               Yes
# 371                        No                                No
# 372                        No                               Yes
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 0                       No                                 No
# 1                       No                                 No
# 2                       No                                 No
# 3                       No                                 No
# 4                       No                                Yes
# ..                     ...                                ...
# 368                     No                                Yes
# 369                    Yes                                 No
# 370                    Yes                                 No
# 371                     No                                Yes
# 372                    Yes                                 No
#
#     Do you consider your home to be in the United States or Abroad?  \
# 0                                        United States
# 1                                        United States
# 2                                        United States
# 3                                               Abroad
# 4                                        United States
# ..                                                 ...
# 368                                      United States
# 369                                             Abroad
# 370                                             Abroad
# 371                                      United States
# 372                                             Abroad
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 0                            In-State            Yes  ...
# 1                            In-State             No  ...
# 2                        Out-of-State            Yes  ...
# 3                        Out-of-State             No  ...
# 4                            In-State             No  ...
# ..                                ...            ...  ...
# 368                          In-State            Yes  ...
# 369                      Out-of-State            Yes  ...
# 370                      Out-of-State            Yes  ...
# 371                          In-State             No  ...
# 372                          In-State             No  ...
#
#     What college is your major a part of?  \
# 0                                     LAS
# 1                                Grainger
# 2                                     NaN
# 3                                    Gies
# 4                    Information Scineces
# ..                                    ...
# 368                               iSchool
# 369                                   LAS
# 370                                   LAS
# 371                                  Gies
# 372                            Statistics
#
#     What do you think is the hardest college major?  \
# 0                                  Computer Science
# 1                                                CS
# 2                                               NaN
# 3                                              Math
# 4                              Chemical Engineering
# ..                                              ...
# 368                                              CS
# 369                                              CS
# 370                                Computer Science
# 371                                         Physics
# 372                                     Programming
#
#     What genre of music do you listen to?  \
# 0                                     pop
# 1                                     Pop
# 2                                     NaN
# 3                                    Jazz
# 4                                 Hip Hop
# ..                                    ...
# 368                                   R&B
# 369                                   Rap
# 370                                   pop
# 371                                   Pop
# 372                             Pop music
#
#     What is the best boba place in Urbana-Champaign?  \
# 0                                              LaTea
# 1                                               IDK?
# 2                                                NaN
# 3                                           Tea Moji
# 4                                       I don't know
# ..                                               ...
# 368                                     Tiger Sugar
# 369                                          Teamoji
# 370                                       Kungfu Tea
# 371                                              KFT
# 372                                          No idea
#
#     What is your favorite color? What is your favorite food?  \
# 0                           pink                       Tacos
# 1                         Purple                         BBQ
# 2                            NaN                         NaN
# 3                           Blue                         NaN
# 4                            Red              Plantain chips
# ..                           ...                         ...
# 368                        Green                       Sushi
# 369                        White                     Hot pot
# 370                         blue                     Chinese
# 371                          Red                       Sushi
# 372                       Purple                        Beef
#
#     What is your favorite music artist? What is your favorite TV show?  \
# 0                          Taylor Swift    How to Get Away with Murder
# 1                          Taylor Swift                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                   Breaking Bad
# 4                               J. Cole                            BMF
# ..                                  ...                            ...
# 368                          The Weeknd                  One Tree Hill
# 369                        Taylor Swift                         Office
# 370                            Jay Chou                  Young Sheldon
# 371                          Bruno Mars                     The Office
# 372                            Dao Lang                           News
#
#     What's your favorite social media app?  \
# 0                                Instagram
# 1                                  YouTube
# 2                                      NaN
# 3                                  Discord
# 4                                Instagram
# ..                                     ...
# 368                                 TikTok
# 369                               Twitter
# 370                                 WeChat
# 371                                Twitter
# 372                                 WeChat
#
#     Which European country would you like to visit?
# 0                                             Italy
# 1                                             Spain
# 2                                               NaN
# 3                                       Switzerland
# 4                                          Portugal
# ..                                              ...
# 368                                     Montenegro
# 369                                          France
# 370                                         England
# 371                                          Sweden
# 372                                          Greece
#
# [373 rows x 91 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df_hello) == 373), "This is not the Hello dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Classes v. Sleep
#
# With the Hello Dataset, we are going to briefly explore two quantitative questions posed and answered by all DISCOVERY students and staff:
# - How many hours do you sleep in a day?
# - How many classes are you taking this semester?

# %% [markdown]
# ### Puzzle 2.1: Observation Subsets
#
# In this situation, let's define the daily routine of **6 or more hours** of sleep as "good sleep" and any less to be defined as "bad sleep".
#
# From this, create two DataFrames that contain subsets of the Hello Dataset:
# - `good_sleep`: including everyone who gets "good sleep" on average ($\space \geq 6 \space$)
# - `bad_sleep`: including everyone who gets "bad sleep" on average ($\space < 6 \space$)
#
# The `sleep` question has been provided to you as a **string** for ease of DataFrame column access.

# %%
sleep = 'How many hours do you sleep in a day?'
good_sleep = df_hello[df_hello[sleep] >= 6]
good_sleep
# Out:
#            Name   Section  Are you a "Type A" or "Type B" personality?  \
# 0    Prof Karle       AL1        Type B (patient, flexible, laid-back)
# 1     Prof Wade       AL1  Type A (ambitious, competitive, aggressive)
# 2         Harsh       AYB  Type A (ambitious, competitive, aggressive)
# 3       Norman        AYO        Type B (patient, flexible, laid-back)
# 5      TA Faaez  AYB, AYC        Type B (patient, flexible, laid-back)
# ..          ...       ...                                          ...
# 368      Maryam       AYC  Type A (ambitious, competitive, aggressive)
# 369        Nick       AYB  Type A (ambitious, competitive, aggressive)
# 370       Bowei       AYE        Type B (patient, flexible, laid-back)
# 371        Sean       AYF        Type B (patient, flexible, laid-back)
# 372   TA Yiming  AYO, AYQ  Type A (ambitious, competitive, aggressive)
#
#     Are you a morning person? Are you an international student?  \
# 0                          No                                No
# 1                          No                                No
# 2                         Yes                               Yes
# 3                          No                               Yes
# 5                         Yes                               Yes
# ..                        ...                               ...
# 368                        No                                No
# 369                        No                               Yes
# 370                        No                               Yes
# 371                        No                                No
# 372                        No                               Yes
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 0                       No                                 No
# 1                       No                                 No
# 2                       No                                 No
# 3                       No                                 No
# 5                       No                                 No
# ..                     ...                                ...
# 368                     No                                Yes
# 369                    Yes                                 No
# 370                    Yes                                 No
# 371                     No                                Yes
# 372                    Yes                                 No
#
#     Do you consider your home to be in the United States or Abroad?  \
# 0                                        United States
# 1                                        United States
# 2                                        United States
# 3                                               Abroad
# 5                                               Abroad
# ..                                                 ...
# 368                                      United States
# 369                                             Abroad
# 370                                             Abroad
# 371                                      United States
# 372                                             Abroad
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 0                            In-State            Yes  ...
# 1                            In-State             No  ...
# 2                        Out-of-State            Yes  ...
# 3                        Out-of-State             No  ...
# 5                        Out-of-State             No  ...
# ..                                ...            ...  ...
# 368                          In-State            Yes  ...
# 369                      Out-of-State            Yes  ...
# 370                      Out-of-State            Yes  ...
# 371                          In-State             No  ...
# 372                          In-State             No  ...
#
#     What college is your major a part of?  \
# 0                                     LAS
# 1                                Grainger
# 2                                     NaN
# 3                                    Gies
# 5                                Grainger
# ..                                    ...
# 368                               iSchool
# 369                                   LAS
# 370                                   LAS
# 371                                  Gies
# 372                            Statistics
#
#     What do you think is the hardest college major?  \
# 0                                  Computer Science
# 1                                                CS
# 2                                               NaN
# 3                                              Math
# 5                                       Mathematics
# ..                                              ...
# 368                                              CS
# 369                                              CS
# 370                                Computer Science
# 371                                         Physics
# 372                                     Programming
#
#     What genre of music do you listen to?  \
# 0                                     pop
# 1                                     Pop
# 2                                     NaN
# 3                                    Jazz
# 5                                     Pop
# ..                                    ...
# 368                                   R&B
# 369                                   Rap
# 370                                   pop
# 371                                   Pop
# 372                             Pop music
#
#     What is the best boba place in Urbana-Champaign?  \
# 0                                              LaTea
# 1                                               IDK?
# 2                                                NaN
# 3                                           Tea Moji
# 5                                        Kung Fu Tea
# ..                                               ...
# 368                                     Tiger Sugar
# 369                                          Teamoji
# 370                                       Kungfu Tea
# 371                                              KFT
# 372                                          No idea
#
#     What is your favorite color? What is your favorite food?  \
# 0                           pink                       Tacos
# 1                         Purple                         BBQ
# 2                            NaN                         NaN
# 3                           Blue                         NaN
# 5                            Red                       Ramen
# ..                           ...                         ...
# 368                        Green                       Sushi
# 369                        White                     Hot pot
# 370                         blue                     Chinese
# 371                          Red                       Sushi
# 372                       Purple                        Beef
#
#     What is your favorite music artist? What is your favorite TV show?  \
# 0                          Taylor Swift    How to Get Away with Murder
# 1                          Taylor Swift                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                   Breaking Bad
# 5                            The Weeknd            House of the Dragon
# ..                                  ...                            ...
# 368                          The Weeknd                  One Tree Hill
# 369                        Taylor Swift                         Office
# 370                            Jay Chou                  Young Sheldon
# 371                          Bruno Mars                     The Office
# 372                            Dao Lang                           News
#
#     What's your favorite social media app?  \
# 0                                Instagram
# 1                                  YouTube
# 2                                      NaN
# 3                                  Discord
# 5                                Instagram
# ..                                     ...
# 368                                 TikTok
# 369                               Twitter
# 370                                 WeChat
# 371                                Twitter
# 372                                 WeChat
#
#     Which European country would you like to visit?
# 0                                             Italy
# 1                                             Spain
# 2                                               NaN
# 3                                       Switzerland
# 5                                             Paris
# ..                                              ...
# 368                                     Montenegro
# 369                                          France
# 370                                         England
# 371                                          Sweden
# 372                                          Greece
#
# [346 rows x 91 columns]

# %%
bad_sleep = df_hello[df_hello[sleep] < 6]
bad_sleep
# Out:
#               Name   Section  Are you a "Type A" or "Type B" personality?  \
# 4          Christ`       AYM  Type A (ambitious, competitive, aggressive)
# 25         Ibrahim       AYK        Type B (patient, flexible, laid-back)
# 36           Aanvi       AYO  Type A (ambitious, competitive, aggressive)
# 46             Joy       AYA        Type B (patient, flexible, laid-back)
# 48             Ani       AYA        Type B (patient, flexible, laid-back)
# 68       Marshall        AYD        Type B (patient, flexible, laid-back)
# 73   TA Evangelos   AYE, AYI        Type B (patient, flexible, laid-back)
# 109         Yoshee       AYM  Type A (ambitious, competitive, aggressive)
# 138          Ausar       AYA        Type B (patient, flexible, laid-back)
# 157         CA Ram       AYP        Type B (patient, flexible, laid-back)
# 174        Vedaant       AYQ        Type B (patient, flexible, laid-back)
# 175          Shiya       AYM        Type B (patient, flexible, laid-back)
# 184          Goose       AYP        Type B (patient, flexible, laid-back)
# 188          Emily       AYI        Type B (patient, flexible, laid-back)
# 197           Toby       AYK        Type B (patient, flexible, laid-back)
# 200         Ayares       AYO  Type A (ambitious, competitive, aggressive)
# 218        Anthony       AYO        Type B (patient, flexible, laid-back)
# 251            Sam       AYP        Type B (patient, flexible, laid-back)
# 252        Janella       AYD        Type B (patient, flexible, laid-back)
# 271      Guillermo       AYI  Type A (ambitious, competitive, aggressive)
# 297           Jose       AYE        Type B (patient, flexible, laid-back)
# 300          Peter       AYP  Type A (ambitious, competitive, aggressive)
# 301         Santos       AYF  Type A (ambitious, competitive, aggressive)
# 310         hannah       AYD        Type B (patient, flexible, laid-back)
# 330         Skylar       AYO        Type B (patient, flexible, laid-back)
# 334         Mickie       AYB  Type A (ambitious, competitive, aggressive)
# 344        Shynna        AYK        Type B (patient, flexible, laid-back)
#
#     Are you a morning person? Are you an international student?  \
# 4                         Yes                                No
# 25                        Yes                                No
# 36                        Yes                               Yes
# 46                         No                                No
# 48                         No                               Yes
# 68                        Yes                                No
# 73                        Yes                               Yes
# 109                        No                               Yes
# 138                        No                                No
# 157                       Yes                               Yes
# 174                       Yes                               Yes
# 175                        No                               Yes
# 184                       Yes                                No
# 188                       Yes                                No
# 197                       Yes                                No
# 200                       Yes                                No
# 218                        No                               Yes
# 251                        No                                No
# 252                        No                                No
# 271                       Yes                                No
# 297                       Yes                                No
# 300                       Yes                               Yes
# 301                        No                                No
# 310                        No                                No
# 330                        No                               Yes
# 334                        No                                No
# 344                        No                                No
#
#     Are you an only child? Are you from the Chicagoland area?  \
# 4                       No                                Yes
# 25                      No                                Yes
# 36                      No                                 No
# 46                      No                                Yes
# 48                      No                                 No
# 68                      No                                 No
# 73                      No                                 No
# 109                    Yes                                 No
# 138                     No                                Yes
# 157                    Yes                                 No
# 174                    Yes                                 No
# 175                     No                                 No
# 184                     No                                Yes
# 188                     No                                 No
# 197                     No                                Yes
# 200                    Yes                                Yes
# 218                    Yes                                 No
# 251                     No                                 No
# 252                     No                                Yes
# 271                     No                                 No
# 297                     No                                Yes
# 300                     No                                 No
# 301                     No                                Yes
# 310                     No                                Yes
# 330                     No                                 No
# 334                     No                                 No
# 344                     No                                Yes
#
#     Do you consider your home to be in the United States or Abroad?  \
# 4                                        United States
# 25                                       United States
# 36                                              Abroad
# 46                                       United States
# 48                                       United States
# 68                                       United States
# 73                                       United States
# 109                                             Abroad
# 138                                      United States
# 157                                             Abroad
# 174                                             Abroad
# 175                                             Abroad
# 184                                      United States
# 188                                      United States
# 197                                      United States
# 200                                      United States
# 218                                             Abroad
# 251                                             Abroad
# 252                                      United States
# 271                                      United States
# 297                                      United States
# 300                                             Abroad
# 301                                      United States
# 310                                      United States
# 330                                             Abroad
# 334                                      United States
# 344                                      United States
#
#     Are you in-state or out-of-state? Are you tired?  ...  \
# 4                            In-State             No  ...
# 25                           In-State            Yes  ...
# 36                       Out-of-State            Yes  ...
# 46                           In-State             No  ...
# 48                       Out-of-State            Yes  ...
# 68                           In-State            Yes  ...
# 73                       Out-of-State             No  ...
# 109                      Out-of-State            Yes  ...
# 138                          In-State            Yes  ...
# 157                      Out-of-State            Yes  ...
# 174                      Out-of-State            Yes  ...
# 175                      Out-of-State            Yes  ...
# 184                          In-State            Yes  ...
# 188                      Out-of-State            Yes  ...
# 197                          In-State            Yes  ...
# 200                          In-State            Yes  ...
# 218                      Out-of-State            Yes  ...
# 251                          In-State            Yes  ...
# 252                          In-State            Yes  ...
# 271                          In-State            Yes  ...
# 297                          In-State             No  ...
# 300                      Out-of-State            Yes  ...
# 301                          In-State            Yes  ...
# 310                          In-State            Yes  ...
# 330                          In-State            Yes  ...
# 334                          In-State            Yes  ...
# 344                          In-State            Yes  ...
#
#         What college is your major a part of?  \
# 4                        Information Scineces
# 25   School of Information Sciences (ISchool)
# 36                                   Grainger
# 46                                       Gies
# 48                       Grainger Engineering
# 68                                        LAS
# 73                                          1
# 109                                  Grainger
# 138                                      ACES
# 157                                       LAS
# 174                                       LAS
# 175                                  Grainger
# 184                                   iSchool
# 188                                  I school
# 197                                  I-School
# 200                                       LAS
# 218                                       LAS
# 251                                       LAS
# 252                                   iSchool
# 271                                      ACES
# 297                                      ACES
# 300                                      Gies
# 301                                       LAS
# 310                                      gies
# 330                                       DGS
# 334                                   iSchool
# 344                  Gies College of Business
#
#     What do you think is the hardest college major?  \
# 4                              Chemical Engineering
# 25                          Biochemical Engineering
# 36                            Computer Engineering
# 46                                      mathematics
# 48                           Electrical Engineering
# 68                                              Art
# 73                                      Mathematics
# 109                                             ECE
# 138                          mechanical engineering
# 157                                    Mathematics
# 174                                         Physics
# 175                                             ECE
# 184                                     engineering
# 188                            Computer Engineering
# 197                        something in engineering
# 200                                     Engineering
# 218                                    Data Science
# 251                         Electrical Engineering
# 252                                     Engineering
# 271                                     IOnknow tbh
# 297                                     Engineering
# 300                                              CS
# 301                                Computer Science
# 310                                     engineering
# 330                                            math
# 334                                    Engineering
# 344                          Aerospace Engineering
#
#     What genre of music do you listen to?  \
# 4                                 Hip Hop
# 25                             Everything
# 36                                   Pop
# 46                             everything
# 48                                   Rock
# 68                               Alt-Rock
# 73                             Rock music
# 109                                Low-fi
# 138                    hip hop, rock, r&b
# 157                                 K-Pop
# 174                             Classical
# 175                                  Rock
# 184                                   rap
# 188                             Pop Chill
# 197                             indie/alt
# 200                                  Rock
# 218                                   All
# 251                            Indie Rock
# 252                                 J-POP
# 271                    Any except country
# 297                               Hip Hop
# 300                               country
# 301                                  Rock
# 310                                   pop
# 330                          Pop Rock R&B
# 334                                   Pop
# 344                            Indie Rock
#
#     What is the best boba place in Urbana-Champaign?  \
# 4                                       I don't know
# 25                                       Kung Fu Tea
# 36                                       kungFu tea
# 46                                          cocomero
# 48                                        Infinitea
# 68                                      None of them
# 73                                      I don't know
# 109                                          Teamoji
# 138                                              NaN
# 157                                          Teamoji
# 174                                          Kung Fu
# 175                                      Kung Fu Tea
# 184                                              NaN
# 188                                            Tenko
# 197                                i don't like boba
# 200                                      Kung Fu Tea
# 218                                         Yuan cha
# 251                                          Teamoji
# 252                                              KFT
# 271                                 Make it yourself
# 297                                     I don't know
# 300                                      Tiger Sugar
# 301                                     I don't know
# 310                                      tiger sugar
# 330                                         moge tea
# 334                                        Cafe Bene
# 344                                          Teamoji
#
#     What is your favorite color? What is your favorite food?  \
# 4                            Red              Plantain chips
# 25                        Yellow                  Sandwiches
# 36                          Blue                    Bhelpuri
# 46                         Black                        roce
# 48                          Blue          Crunchwrap Supreme
# 68                         Green                   Pierogies
# 73                          Grey                       Pasta
# 109                          Red                         NaN
# 138                        green               Cheeseburgers
# 157                         Blue                       Ramen
# 174                       Purple                       Pizza
# 175                       Purple                       pasta
# 184                        green                       kitfo
# 188                         Blue                  Ice cream
# 197                   navy blue                 Indian Food
# 200                   Dark Green                     Mexican
# 218                        Black                     Sashimi
# 251                         Blue                       pasta
# 252                        green                       Sushi
# 271                         Blue                       Wings
# 297                          red                     Tamales
# 300                         blue                   Thai food
# 301                        Green                       Tacos
# 310                       purple                    skittles
# 330                        white           chicken wings!!!!
# 334                       Orange                    Crawfish
# 344                 Forest Green                       Tacos
#
#     What is your favorite music artist?     What is your favorite TV show?  \
# 4                               J. Cole                                BMF
# 25                          Stupendium                          Community
# 36                        Charlie Puth        Tarak Mehta ka Ulta Chashma
# 46                                Drake        How To Get Away With Murder
# 48                         Led Zeppelin                       Black Mirror
# 68                                JAWNY                         Inside Job
# 73                          Hilary Hahn                               Dark
# 109                       One Direction              How I Met Your Mother
# 138           Kanye west, drake, j cole           The boys, Rick and Morty
# 157                               TWICE             STAT 385 video lessons
# 174                        Arijit Singh                           The Boys
# 175                         Linkin Park                            FRIENDS
# 184                          Juice WRLD                   too many to pick
# 188                      Olivia Rodrigo                   Singles Inferno
# 197                      Clairo/Wallows                     Gilmore Girls
# 200                              Mitski                          Severance
# 218                          Eason Chen                                Non
# 251                            Good Kid                 Umbrella Academy
# 252                                Joji                     Criminal Minds
# 271                            Kendrick  It's Always Sunny In Philadelphia
# 297                             G herbo                   The good doctor
# 300                          Bruno Mars                             4kings
# 301                   Vicente Fernandez              Malcolm in the middle
# 310                                ruel                         the office
# 330                               Adele                     2 Broken girls
# 334                           Kennie JD                     Schitt's Creek
# 344                      Kendrick Lamar                             Naruto
#
#     What's your favorite social media app?  \
# 4                                Instagram
# 25                                 Reddit
# 36                              Instagram
# 46                               Instagram
# 48                                  Reddit
# 68                                  Reddit
# 73                              Instagram
# 109                                    NaN
# 138                              Instagram
# 157                                Discord
# 174                              Instagram
# 175                               Whatsapp
# 184                               snapchat
# 188                             Instagram
# 197                                TikTok
# 200                              Pinterest
# 218                 Tiktok Chinese version
# 251                                   None
# 252                                 TikTok
# 271                                Twitter
# 297                               Snapchat
# 300                              Instagram
# 301                                Youtube
# 310                                 tiktok
# 330                              instagram
# 334                               Snapchat
# 344                              instagram
#
#     Which European country would you like to visit?
# 4                                          Portugal
# 25                                        Istanbul
# 36                                           Norway
# 46                                           France
# 48                                            Spain
# 68                                          Iceland
# 73                                          Denmark
# 109                                     Switzerland
# 138                                           italy
# 157                                     Switzerland
# 174                                           Italy
# 175                                          Greece
# 184                                         england
# 188                                          France
# 197                                         France
# 200                                           Italy
# 218                                         Iceland
# 251                                          Sweden
# 252                                           Italy
# 271                                           Spain
# 297                                         Germany
# 300                                          France
# 301                                           Italy
# 310                                         germany
# 330                                         Iceland
# 334                                           Spain
# 344                                         Iceland
#
# [27 rows x 91 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(good_sleep) == 346  ), "Double check your conditional used to create df_goodsleep from df_hello - remember, good sleep is response values of 6 hours or more"
assert(len(bad_sleep) == 27 ), "Double check your conditional used to create df_badsleep from df_hello - remember, bad sleep is response values of less than 6 hours"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Average Number of Classes by Group
#
# Now find the **average number of classes** of each group (`good_sleep` and `bad_sleep`):
#
# - The `df['column name'].mean()` function returns the mean of all values in the specified column of `df`
# - The `classes` question has been provided to you as a **string** for ease of DataFrame column access.

# %%
classes = 'How many classes are you taking this semester?'
good_sleep_avg_classes = good_sleep[classes].mean()
good_sleep_avg_classes
# Out:
# 5.037900874635569

# %%
bad_sleep_avg_classes = bad_sleep[classes].mean()
bad_sleep_avg_classes
# Out:
# 5.111111111111111

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(math.isclose(good_sleep_avg_classes,  5.037900874635569)), "The average number of classes for those with good sleep does not appear to have been correctly calculated"
assert(math.isclose(bad_sleep_avg_classes,  5.111111111111111)), "The average number of classes for those with bad sleep does not appear to have been correctly calculated"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analyis: Classes v. Sleeptime

# %% [markdown]
# **Q: What is the relationship between classes and daily sleep time?  Can you think of a possible *confounding variable* in the observed relationship (or lack thereof) between classes and daily sleep time?** Write at least three complete sentences.

# %% [markdown]
# The relationship between classes and daily sleep time is that people with good sleep take less classes on average. A possible confounder for this could be the individuals major and how many hours they have to spend studying per class. Another counfounder could be credit hours because some classes may be 1 or 2 credit hours while others are 4 credit hours, therefore requiring more hours awake and dedicated to studying.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
