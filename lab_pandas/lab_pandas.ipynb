# %% [markdown]
# # Welcome to lab_🐼s!
#
# Last week, you did amazing work in setting up your computer to do Data Science!  Let's now do Data Science on your computer for the first time!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 0: Your Lab Group!
#
# We find it's best when you're programming with a group of people who you can help out and can help you out!
#
# - A key part of Data Science is being able to **communicate about your work**.  If you are the best programmer in the world, but no one uses your code, then the code you're writing is not getting run.  By learning strong communication skills, you will be able to **explain your code**, and the underlying data science concepts, to everyone -- data scientists and non-scientists alike!
#
# - **Every lab** you will need to complete some parts of the lab **with your group**.  There will be both **"group discussions"** and **"individual reflections"** as part of every lab.

# %% [markdown]
# ## Create Your Group
#
# If you have not done so already, **RIGHT NOW** find *(ideally)* two other people to make a group of **two, three, or four** people.   *(We find groups of three work the best, but you can be a group of two or four -- no solo groups, and no groups of five!*)
#
# - If you're at a group of five, split into a group of two and a group of three.  You can still help each other as a larger group, but the group questions should be answered in your smaller group of 2-4 people.
#
# Once you have your group **introduce yourselves to each other! :)**

# %% [markdown]
# ## Record Your Group
#
# Since you know Python, edit the following cell to add strings about your group:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Kim"
ca1_name = "Jai"
ca2_name = "Mia"


# As part of your introduction, learn your lab partner's name, major, and
# learn something new about them that you never knew!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Archit"
partner1_netid = "architk2"
partner1_major = "Physics"

partner2_name = "Kasra"
partner2_netid = "kvak12"
partner2_major = "undeclared"

partner3_name = "Brian"
partner3_netid = "bmarti64"
partner3_major = "Civil Engineering "

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: 🧑‍🤝‍🧑 Hello Dataset!

# %% [markdown]
# In lecture, we have already began to explore the "Party Dataset" that you created.  We will continue to use the Party Dataset all semester long, but we want even more datasets -- and we want you to come up with the questions!
#
# In this lab, **you** will come up with questions to ask the entire class for the **"Hello Dataset"**!

# %% [markdown]
# ## Hello Dataset Overview
#
# Soon after this lab, your homework will be to fill out a class-wide "Hello Survey".  Right now, with your group, you will come up some of the questions that should be on this survey *(and you will do analysis on your questions next week!)*.
#
# With your group, come up with four questions below!  Before you get started, a few notes:
#
# - The survey will be **NOT be anonymous** and the results will be shared with the class to do analysis on, so you should **only ask questions you feel comfortable to share with the class**.
# - **Questions that are inappropriate** for a classroom environment will be thrown out and you won't earn lab credit points for any question we throw out.  (Keep everything at most PG/PG-13.)
# - You are going to submit **one set of questions for your whole group**.  You must decide on the questions together.

# %% [markdown]
# ## Q1: Question with a Binary Response
#
# A question with a **binary response** is a question that has only two answers.  For example:
# - *Do you prefer cats or dogs?*
# - *Were you born in Illinois?*
#
# With your group (you must all decide on a single question together), come up with a question that you think will have **exactly 50%/50%** split between the two binary outcomes.  *(The question that gets closest to 50%/50% will get extra credit!)*

# %% [markdown]
# **What is your binary question?**
#
# *Do you prefer winter or summer?*

# %% [markdown]
# **Why do you think this is a good question?  Write at least two complete sentences on why you believe your question will have a 50%/50% split.**
#
# *It has two set answers that are different enough to polarize the classes opinions. Winter and summer are complete opposites so we hope this will encourage that split.*

# %% [markdown]
# ## Q2: Question with a Numeric Response
#
# A question with a **numeric response** requires a number for an answer.  For example:
#
# - *What is your height?*
# - *What day were you born?*
#
# With your group (you must all decide on a single question together), come up with a question and a prediction on what you think the most frequent answer will be to your question.

# %% [markdown]
# **What is your numeric question?**
#
# *How many classes are you taking?*

# %% [markdown]
# **What do you think the most frequent answer will be?**
#
# *We predict the most frequent answer to be 4 classes *

# %% [markdown]
# **Why do you think this answer will be the most frequent answer?  Write at least one complete sentences on why you believe that it will be the most frequent answer.**
#
# We said this because the range of credit hours is usually 14-16 which usually corresponds with 4 courses.

# %% [markdown]
# ## Q3: Question with a (non-numeric) Textual Response
#
# A question with a (non-numeric) **textual response** requires a word or two for an answer.  For example:
#
# - *What is your favorite sport to play?*
# - *What is the location of your favorite trip/vacation?*
#
# With your group (you must all decide on a single question together), come up with a question where at least two members of your group share the same answer.

# %% [markdown]
# **What is your textual response question?**
#
# *What is your favorite holiday?

# %% [markdown]
# **What is the shared answer between your group?  Do you also share this answer (if not, what's your answer to the question)?**
#
# We were split between Christmas and Halloween. I prefer Halloween.

# %% [markdown]
# ## Q4: Open Question
#
# One final question -- no restrictions on the format!  Is there a great question your group discussed that you did not get to use one of the first three questions but you want to know the classes' answer?

# %% [markdown]
# **What is your final question for the whole class?**
#
# What school year are you?

# %% [markdown]
# ## Submit Your Questions to Your TA
#
# Your lab TAs will be grading your lab notebook for your full responses, but we want to make sure to get the survey with your questions out to everyone ASAP!
#
# - Pick one member of your group as the "question submitter".
# - If you're the question submitter, complete this Google Form for your group (requires @illinois.edu login): https://forms.gle/yMUDTbw9FSpEQ6DF7

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Importing the Course Catalog Dataset
#
# In lecture, you learned we will use the `pandas` **library** for working with data.  Libraries are collections of functions and other objects that extend what Python can do by itself.  The `pandas` library is the most widely used library for data science.
#
# To use the `pandas` library, we must **import** it into your notebook.  In literally every lab, you will need to import the library just like we did in lecture -- import pandas as `pd` in the following cell:

# %%
# Write the code to import pandas as pd:
import pandas as pd

# %% [markdown]
# In lecture, you saw the "Course Catalog" dataset.  Using the `read_csv` function, load the course catalog dataset.  The URL for this dataset is:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog.csv
# ```
#
# Remember, URLs passed to `read_csv` are **string** variables, so remember to use **quotation marks**.

# %%
# Load the course catalog dataset into a variable named `df`:
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")

# %%
# Print out the contents of `df`:
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 4      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 11816  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11817  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11818  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11819  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11820  2023  Spring  2023-sp    ZULU     202            Elementary Zulu II
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 11816                    Same as INFO 303. See INFO 303.     3 hours.
# 11817                    Same as INFO 303. See INFO 303.     3 hours.
# 11818                    Same as INFO 303. See INFO 303.     3 hours.
# 11819                    Same as INFO 303. See INFO 303.     3 hours.
# 11820  Continuation of ZULU 201 with introduction of ...     5 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11816                    Same as INFO 303. See INFO 303.
# 11817                    Same as INFO 303. See INFO 303.
# 11818                    Same as INFO 303. See INFO 303.
# 11819                    Same as INFO 303. See INFO 303.
# 11820  Same as AFST 252. Participation in the languag...
#
#                                        Degree Attributes  ... Section Status  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# ...                                                  ...  ...            ...
# 11816                       Advanced Composition course.  ...              A
# 11817                       Advanced Composition course.  ...              A
# 11818                       Advanced Composition course.  ...              A
# 11819                       Advanced Composition course.  ...              A
# 11820                                                NaN  ...              A
#
#        Enrollment Status                   Type Type Code Start Time  \
# 0                   Open  Discussion/Recitation       DIS   09:00 AM
# 1                   Open  Discussion/Recitation       DIS   10:00 AM
# 2                   Open  Discussion/Recitation       DIS   11:00 AM
# 3                   Open  Discussion/Recitation       DIS   12:00 PM
# 4                   Open  Discussion/Recitation       DIS   01:00 PM
# ...                  ...                    ...       ...        ...
# 11816             Closed                Lecture       LEC   11:00 AM
# 11817      CrossListOpen                Lecture       LEC   11:00 AM
# 11818             Closed                Lecture       LEC   12:30 PM
# 11819             Closed                Lecture       LEC   02:00 PM
# 11820      CrossListOpen     Lecture-Discussion       LCD   ARRANGED
#
#        End Time Days of Week  Room            Building           Instructors
# 0      09:50 AM            F   242         Bevier Hall       Lee, S;Zheng, R
# 1      10:50 AM            F   317   David Kinley Hall        Lee, S;Shin, J
# 2      11:50 AM            F   317   David Kinley Hall        Lee, S;Shin, J
# 3      12:50 PM            F   242         Bevier Hall                Lee, S
# 4      01:50 PM            F   212      Davenport Hall        Lee, S;Wang, Y
# ...         ...          ...   ...                 ...                   ...
# 11816  12:15 PM           TR  3217  Everitt Laboratory           Hamilton, A
# 11817  12:15 PM           TR  3117  Everitt Laboratory         Kapczynski, A
# 11818  01:45 PM           TR  3117  Everitt Laboratory              Gross, H
# 11819  03:15 PM           TR  3217  Everitt Laboratory            Neyhard, Y
# 11820       NaN          NaN   NaN                 NaN  Gathogo, M;Saadah, E
#
# [11821 rows x 27 columns]

# %% [markdown]
# ## 🔬 Test Case Checkpoint 🔬
#
# Throughout the lab, we will have "checkpoints" at key points.  Most checkpoints will include **test cases** that verify that your notebook appears to be correct.
#
# - The test cases are **NOT** a guarantee that everything is perfect, but we try our very best to catch any common mistakes you might make!
# - If you see `AssertionError` error message when running the test case, we provide a helpful hint on what may not be correct.
# - If you see a party popper emoji and a message that all tests pass, you passed the checkpoint!
# - **Checkpoints** are a good time to check with your group to make everyone gets to the checkpoint together!

# %%
## == CHECKPOINT TEST CASES for Part 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "Did you define a variable called df?"
assert( len(df) == 11821 ), "It looks like you did not import the correct dataset?"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: STAT / CS / IS Majors
#
# Data Science DISCOVERY is a unique course that is cross-listed across three departments: Statistics, Computer Science, and Information Sciences.  Let's explore courses from all three of those subjects!

# %% [markdown]
# ### Puzzle 3.1
#
# Select only the rows that have a `Subject` of `STAT`.  Assign this to the variable name `df_STAT` instead of the usual `df`.
# - Make sure your result contains only statistics courses!

# %%
df_STAT = df[df["Subject"] == "STAT"]
df_STAT
# Out:
#        Year    Term YearTerm Subject  Number                           Name  \
# 11086  2023  Spring  2023-sp    STAT     100                     Statistics
# 11087  2023  Spring  2023-sp    STAT     100                     Statistics
# 11088  2023  Spring  2023-sp    STAT     107         Data Science Discovery
# 11089  2023  Spring  2023-sp    STAT     107         Data Science Discovery
# 11090  2023  Spring  2023-sp    STAT     107         Data Science Discovery
# ...     ...     ...      ...     ...     ...                            ...
# 11234  2023  Spring  2023-sp    STAT     590  Individual Study and Research
# 11235  2023  Spring  2023-sp    STAT     593                STAT Internship
# 11236  2023  Spring  2023-sp    STAT     593                STAT Internship
# 11237  2023  Spring  2023-sp    STAT     595       Preparing Future Faculty
# 11238  2023  Spring  2023-sp    STAT     599                Thesis Research
#
#                                              Description    Credit Hours  \
# 11086  First course in probability and statistics at ...        3 hours.
# 11087  First course in probability and statistics at ...        3 hours.
# 11088  Data Science Discovery is the intersection of ...        4 hours.
# 11089  Data Science Discovery is the intersection of ...        4 hours.
# 11090  Data Science Discovery is the intersection of ...        4 hours.
# ...                                                  ...             ...
# 11234  Directed reading and research. Approved for le...   0 TO 8 hours.
# 11235  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 11236  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 11237  Prepares Ph.D. students who are interested in ...        2 hours.
# 11238  Approved for S/U grading only. May be repeated...  0 TO 16 hours.
#
#                                             Section Info  \
# 11086  Credit is not given for both STAT 100 and any ...
# 11087  Credit is not given for both STAT 100 and any ...
# 11088                         Same as CS 107 and IS 107.
# 11089                         Same as CS 107 and IS 107.
# 11090                         Same as CS 107 and IS 107.
# ...                                                  ...
# 11234  Approved for letter and S/U grading. May be re...
# 11235  Approved for letter and S/U grading. Prerequis...
# 11236  Approved for letter and S/U grading. Prerequis...
# 11237                                                NaN
# 11238  Approved for S/U grading only. May be repeated...
#
#                       Degree Attributes  ... Section Status  \
# 11086  Quantitative Reasoning I course.  ...              A
# 11087  Quantitative Reasoning I course.  ...              A
# 11088  Quantitative Reasoning I course.  ...              A
# 11089  Quantitative Reasoning I course.  ...              A
# 11090  Quantitative Reasoning I course.  ...              A
# ...                                 ...  ...            ...
# 11234                               NaN  ...              A
# 11235                               NaN  ...              A
# 11236                               NaN  ...              A
# 11237                               NaN  ...              A
# 11238                               NaN  ...              A
#
#        Enrollment Status                   Type Type Code Start Time  \
# 11086  Open (Restricted)                Lecture       LEC   10:00 AM
# 11087             Closed                 Online       ONL   ARRANGED
# 11088      CrossListOpen                Lecture       LEC   12:00 PM
# 11089             Closed  Laboratory-Discussion       LBD   03:30 PM
# 11090             Closed  Laboratory-Discussion       LBD   03:30 PM
# ...                  ...                    ...       ...        ...
# 11234             Closed      Independent Study       IND   ARRANGED
# 11235  Open (Restricted)             Internship       INT   ARRANGED
# 11236  Open (Restricted)             Internship       INT   ARRANGED
# 11237  Open (Restricted)     Lecture-Discussion       LCD   02:00 PM
# 11238             Closed      Independent Study       IND   ARRANGED
#
#        End Time Days of Week   Room                     Building  \
# 11086  10:50 AM          MWF  THEAT                 Lincoln Hall
# 11087       NaN          NaN    NaN                          NaN
# 11088  12:50 PM          MWF  THEAT                 Lincoln Hall
# 11089  04:50 PM            R   1136   Foreign Languages Building
# 11090  04:50 PM            R   1030   Foreign Languages Building
# ...         ...          ...    ...                          ...
# 11234       NaN          NaN    NaN                          NaN
# 11235       NaN          NaN    NaN                          NaN
# 11236       NaN          NaN    NaN                          NaN
# 11237  03:50 PM            W    305  Materials Science & Eng Bld
# 11238       NaN          NaN    NaN                          NaN
#
#                                              Instructors
# 11086                                        Flanagan, K
# 11087                                        Flanagan, K
# 11088                  Fagen-Ulmschneider, W;Flanagan, K
# 11089                                                NaN
# 11090                                                NaN
# ...                                                  ...
# 11234                                                NaN
# 11235  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 11236  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 11237                                            Shao, X
# 11238                                                NaN
#
# [153 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.2
#
# Select only the rows that have a `Subject` of `CS`.  Assign this to the variable name `df_CS` instead of the usual `df`.
# - Make sure your result contains only computer science courses!

# %%
df_CS = df[df["Subject"] == "CS"]
df_CS
# Out:
#       Year    Term YearTerm Subject  Number                              Name  \
# 3040  2023  Spring  2023-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3041  2023  Spring  2023-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3042  2023  Spring  2023-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3043  2023  Spring  2023-sp      CS     101  Intro Computing: Engrg &amp; Sci
# 3044  2023  Spring  2023-sp      CS     101  Intro Computing: Engrg &amp; Sci
# ...    ...     ...      ...     ...     ...                               ...
# 3373  2023  Spring  2023-sp      CS     598                    Special Topics
# 3374  2023  Spring  2023-sp      CS     598                    Special Topics
# 3375  2023  Spring  2023-sp      CS     598                    Special Topics
# 3376  2023  Spring  2023-sp      CS     598                    Special Topics
# 3377  2023  Spring  2023-sp      CS     599                   Thesis Research
#
#                                             Description    Credit Hours  \
# 3040  Fundamental principles, concepts, and methods ...        3 hours.
# 3041  Fundamental principles, concepts, and methods ...        3 hours.
# 3042  Fundamental principles, concepts, and methods ...        3 hours.
# 3043  Fundamental principles, concepts, and methods ...        3 hours.
# 3044  Fundamental principles, concepts, and methods ...        3 hours.
# ...                                                 ...             ...
# 3373  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3374  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3375  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3376  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3377    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 3040  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3041  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3042  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3043  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3044  Prerequisite: One of MATH 220 or MATH 221 or M...
# ...                                                 ...
# 3373  May be repeated in the same or separate terms ...
# 3374  May be repeated in the same or separate terms ...
# 3375  May be repeated in the same or separate terms ...
# 3376  May be repeated in the same or separate terms ...
# 3377    Approved for S/U grading only. May be repeated.
#
#                       Degree Attributes  ... Section Status  \
# 3040  Quantitative Reasoning II course.  ...              A
# 3041  Quantitative Reasoning II course.  ...              A
# 3042  Quantitative Reasoning II course.  ...              A
# 3043  Quantitative Reasoning II course.  ...              P
# 3044  Quantitative Reasoning II course.  ...              A
# ...                                 ...  ...            ...
# 3373                                NaN  ...              A
# 3374                                NaN  ...              A
# 3375                                NaN  ...              A
# 3376                                NaN  ...              A
# 3377                                NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 3040  Open (Restricted)                Lecture       LEC   11:00 AM  11:50 AM
# 3041             Closed  Laboratory-Discussion       LBD   02:00 PM  03:50 PM
# 3042             Closed  Laboratory-Discussion       LBD   04:00 PM  05:50 PM
# 3043             Closed  Laboratory-Discussion       LBD   06:00 PM  07:50 PM
# 3044               Open  Laboratory-Discussion       LBD   09:00 AM  10:50 AM
# ...                 ...                    ...       ...        ...       ...
# 3373             Closed                 Online       E16   ARRANGED       NaN
# 3374  Open (Restricted)                Lecture        L2   02:00 PM  03:15 PM
# 3375  Open (Restricted)     Lecture-Discussion        S8   03:30 PM  04:45 PM
# 3376  Open (Restricted)     Lecture-Discussion       S13   11:00 AM  12:15 PM
# 3377             Closed      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week  Room                     Building            Instructors
# 3040           MW   AUD        Foellinger Auditorium  Beckman, M;Tahboub, R
# 3041            M  L416  Digital Computer Laboratory  Beckman, M;Tahboub, R
# 3042            M  L416  Digital Computer Laboratory  Beckman, M;Tahboub, R
# 3043            M  L416  Digital Computer Laboratory  Beckman, M;Tahboub, R
# 3044            T  L416  Digital Computer Laboratory  Beckman, M;Tahboub, R
# ...           ...   ...                          ...                    ...
# 3373          NaN   NaN                          NaN                 Sun, J
# 3374           TR  1310  Digital Computer Laboratory              Forbes, M
# 3375           TR  2233           Everitt Laboratory               Bates, A
# 3376           WF  3217           Everitt Laboratory               Mehta, R
# 3377          NaN   NaN                          NaN                    NaN
#
# [338 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.3
#
# Select only the rows that have a `Subject` of `IS`.  Assign this to the variable name `df_IS` instead of the usual `df`.
# - Make sure your result contains only information science courses!

# %%
df_IS = df[df["Subject"]=="IS"]
df_IS
# Out:
#       Year    Term YearTerm Subject  Number  \
# 6045  2023  Spring  2023-sp      IS     100
# 6046  2023  Spring  2023-sp      IS     101
# 6047  2023  Spring  2023-sp      IS     101
# 6048  2023  Spring  2023-sp      IS     101
# 6049  2023  Spring  2023-sp      IS     101
# ...    ...     ...      ...     ...     ...
# 6294  2023  Spring  2023-sp      IS     597
# 6295  2023  Spring  2023-sp      IS     597
# 6296  2023  Spring  2023-sp      IS     597
# 6297  2023  Spring  2023-sp      IS     597
# 6298  2023  Spring  2023-sp      IS     599
#
#                                                    Name  \
# 6045   Exploring the iSchool with a Human-Centered Lens
# 6046               Introduction to Information Sciences
# 6047               Introduction to Information Sciences
# 6048               Introduction to Information Sciences
# 6049               Introduction to Information Sciences
# ...                                                 ...
# 6294  Advanced Topics in Data Analytics &amp; Data S...
# 6295  Advanced Topics in Data Analytics &amp; Data S...
# 6296  Advanced Topics in Data Analytics &amp; Data S...
# 6297  Advanced Topics in Data Analytics &amp; Data S...
# 6298                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 6045  This course introduces students to the School ...        1 hours.
# 6046  This course provides an introduction to the fi...        3 hours.
# 6047  This course provides an introduction to the fi...        3 hours.
# 6048  This course provides an introduction to the fi...        3 hours.
# 6049  This course provides an introduction to the fi...        3 hours.
# ...                                                 ...             ...
# 6294  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6295  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6296  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6297  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6298  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 6045  Prerequisite: Restricted to Majors Only; First...
# 6046                                                NaN
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# ...                                                 ...
# 6294  2 or 4 graduate hours. No professional credit....
# 6295  2 or 4 graduate hours. No professional credit....
# 6296  2 or 4 graduate hours. No professional credit....
# 6297  2 or 4 graduate hours. No professional credit....
# 6298  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes  ... Section Status  \
# 6045                                 NaN  ...              A
# 6046  Social & Beh Sci - Soc Sci course.  ...              A
# 6047  Social & Beh Sci - Soc Sci course.  ...              A
# 6048  Social & Beh Sci - Soc Sci course.  ...              A
# 6049  Social & Beh Sci - Soc Sci course.  ...              A
# ...                                  ...  ...            ...
# 6294                                 NaN  ...              A
# 6295                                 NaN  ...              A
# 6296                                 NaN  ...              A
# 6297                                 NaN  ...              A
# 6298                                 NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 6045  Open (Restricted)     Lecture-Discussion       LCD   04:00 PM  04:50 PM
# 6046             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6047               Open  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6048             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# 6049             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 6294  Open (Restricted)                 Online        E3   01:00 PM  03:50 PM
# 6295  Open (Restricted)     Lecture-Discussion        S1   09:00 AM  11:50 AM
# 6296  Open (Restricted)     Lecture-Discussion       LCD   09:00 AM  11:50 AM
# 6297  Open (Restricted)                 Online        E2   02:00 PM  03:55 PM
# 6298  Open (Restricted)      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week Room                        Building            Instructors
# 6045            W  126  Grad Sch of Lib & Info Science              Newell, M
# 6046            R  12A  Grad Sch of Lib & Info Science              Pintar, J
# 6047            R   53  Grad Sch of Lib & Info Science              Pintar, J
# 6048            R  126  Grad Sch of Lib & Info Science              Pintar, J
# 6049            R  315                    Gregory Hall              Pintar, J
# ...           ...  ...                             ...                    ...
# 6294            M  NaN                             NaN             LeBlanc, Z
# 6295            F  131  Grad Sch of Lib & Info Science              Weible, J
# 6296            W  126  Grad Sch of Lib & Info Science              Weible, J
# 6297            T  NaN                             NaN  Hsiao, T;Schneider, J
# 6298          NaN  NaN                             NaN                    NaN
#
# [254 rows x 27 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES for Part 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_IS' in vars() ), "Make certain to name the IS courses df_IS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_IS[df_IS.Subject != "IS"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.4
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject offers the **fewest** course sections?  The **most** course sections?

# %% [markdown]
# STAT offers the fewest course sections and CS offers the most course sections.

# %% [markdown]
# ### Puzzle 3.5
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject has the highest numbered course?  Is there something similar about all of the highest numbered courses?  Write about what you observed!

# %% [markdown]
# They all offer a 599 numbered course. Across all three departments, this course is intended to be taken as part of a research thesis for graduate students.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 4: Your Major

# %% [markdown]
# In this part, you will be exploring **your major** using the Course Catalog dataset.
#
# - Use the primary subject of your **current major** (or, if you're undeclared, your intended major) for this section.
# - Your answers will be different than the rest of your group!

# %% [markdown]
# ### Puzzle 4.1:
#
# Select only the rows that have a `Subject` of your current/intended major.  Assign this to the variable name `mydf` instead of `df`:

# %%
mydf = df[df["Subject"]=="BIOE"]
mydf
# Out:
#       Year    Term YearTerm Subject  Number  \
# 1586  2023  Spring  2023-sp    BIOE     120
# 1587  2023  Spring  2023-sp    BIOE     200
# 1588  2023  Spring  2023-sp    BIOE     202
# 1589  2023  Spring  2023-sp    BIOE     202
# 1590  2023  Spring  2023-sp    BIOE     202
# 1591  2023  Spring  2023-sp    BIOE     202
# 1592  2023  Spring  2023-sp    BIOE     202
# 1593  2023  Spring  2023-sp    BIOE     205
# 1594  2023  Spring  2023-sp    BIOE     210
# 1595  2023  Spring  2023-sp    BIOE     297
# 1596  2023  Spring  2023-sp    BIOE     303
# 1597  2023  Spring  2023-sp    BIOE     303
# 1598  2023  Spring  2023-sp    BIOE     303
# 1599  2023  Spring  2023-sp    BIOE     306
# 1600  2023  Spring  2023-sp    BIOE     306
# 1601  2023  Spring  2023-sp    BIOE     310
# 1602  2023  Spring  2023-sp    BIOE     360
# 1603  2023  Spring  2023-sp    BIOE     397
# 1604  2023  Spring  2023-sp    BIOE     414
# 1605  2023  Spring  2023-sp    BIOE     415
# 1606  2023  Spring  2023-sp    BIOE     415
# 1607  2023  Spring  2023-sp    BIOE     415
# 1608  2023  Spring  2023-sp    BIOE     415
# 1609  2023  Spring  2023-sp    BIOE     415
# 1610  2023  Spring  2023-sp    BIOE     416
# 1611  2023  Spring  2023-sp    BIOE     416
# 1612  2023  Spring  2023-sp    BIOE     420
# 1613  2023  Spring  2023-sp    BIOE     435
# 1614  2023  Spring  2023-sp    BIOE     436
# 1615  2023  Spring  2023-sp    BIOE     479
# 1616  2023  Spring  2023-sp    BIOE     481
# 1617  2023  Spring  2023-sp    BIOE     481
# 1618  2023  Spring  2023-sp    BIOE     484
# 1619  2023  Spring  2023-sp    BIOE     484
# 1620  2023  Spring  2023-sp    BIOE     486
# 1621  2023  Spring  2023-sp    BIOE     486
# 1622  2023  Spring  2023-sp    BIOE     487
# 1623  2023  Spring  2023-sp    BIOE     497
# 1624  2023  Spring  2023-sp    BIOE     498
# 1625  2023  Spring  2023-sp    BIOE     499
# 1626  2023  Spring  2023-sp    BIOE     500
# 1627  2023  Spring  2023-sp    BIOE     570
# 1628  2023  Spring  2023-sp    BIOE     570
# 1629  2023  Spring  2023-sp    BIOE     572
# 1630  2023  Spring  2023-sp    BIOE     572
# 1631  2023  Spring  2023-sp    BIOE     574
# 1632  2023  Spring  2023-sp    BIOE     574
# 1633  2023  Spring  2023-sp    BIOE     575
# 1634  2023  Spring  2023-sp    BIOE     575
# 1635  2023  Spring  2023-sp    BIOE     580
# 1636  2023  Spring  2023-sp    BIOE     588
# 1637  2023  Spring  2023-sp    BIOE     597
# 1638  2023  Spring  2023-sp    BIOE     598
# 1639  2023  Spring  2023-sp    BIOE     598
# 1640  2023  Spring  2023-sp    BIOE     598
# 1641  2023  Spring  2023-sp    BIOE     598
# 1642  2023  Spring  2023-sp    BIOE     598
# 1643  2023  Spring  2023-sp    BIOE     598
# 1644  2023  Spring  2023-sp    BIOE     599
#
#                                                    Name  \
# 1586                     Introduction to Bioengineering
# 1587                    Bioengineering Career Immersion
# 1588                  Cell &amp; Tissue Engineering Lab
# 1589                  Cell &amp; Tissue Engineering Lab
# 1590                  Cell &amp; Tissue Engineering Lab
# 1591                  Cell &amp; Tissue Engineering Lab
# 1592                  Cell &amp; Tissue Engineering Lab
# 1593                  Signals &amp; Systems in Bioengrg
# 1594         Linear Algebra for Biomedical Data Science
# 1595                                   Individual Study
# 1596                        Quantitative Physiology Lab
# 1597                        Quantitative Physiology Lab
# 1598                        Quantitative Physiology Lab
# 1599                                 Biofabrication Lab
# 1600                                 Biofabrication Lab
# 1601            Computational Tools for Biological Data
# 1602                   Transport &amp; Flow in Bioengrg
# 1603                                   Individual Study
# 1604                         Biomedical Instrumentation
# 1605                     Biomedical Instrumentation Lab
# 1606                     Biomedical Instrumentation Lab
# 1607                     Biomedical Instrumentation Lab
# 1608                     Biomedical Instrumentation Lab
# 1609                     Biomedical Instrumentation Lab
# 1610                                         Biosensors
# 1611                                         Biosensors
# 1612                          Intro Bio Control Systems
# 1613                                    Senior Design I
# 1614                                   Senior Design II
# 1615                              Cancer Nanotechnology
# 1616                     Whole-Body Musculoskel Biomech
# 1617                     Whole-Body Musculoskel Biomech
# 1618          Statistical Analysis of Biomedical Images
# 1619          Statistical Analysis of Biomedical Images
# 1620       Applied Deep Learning for Biomedical Imaging
# 1621       Applied Deep Learning for Biomedical Imaging
# 1622                           Stem Cell Bioengineering
# 1623                                   Individual Study
# 1624                                     Special Topics
# 1625                                      Senior Thesis
# 1626                                   Graduate Seminar
# 1627                                     Seminar Series
# 1628                                     Seminar Series
# 1629                          Biological Measurement II
# 1630                          Biological Measurement II
# 1631  Innovation and Introduction to Financial Decis...
# 1632  Innovation and Introduction to Financial Decis...
# 1633                                   Capstone Project
# 1634                                   Capstone Project
# 1635                     Foundations of Imaging Science
# 1636  Biomedical Image Computing Capstone Project Li...
# 1637                                   Individual Study
# 1638                                     Special Topics
# 1639                                     Special Topics
# 1640                                     Special Topics
# 1641                                     Special Topics
# 1642                                     Special Topics
# 1643                                     Special Topics
# 1644                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 1586  Lectures and discussions of recent trends in b...        1 hours.
# 1587  This course provides exposure to Bioengineerin...        1 hours.
# 1588  Principles of cell biology inherent in tissue ...        2 hours.
# 1589  Principles of cell biology inherent in tissue ...        2 hours.
# 1590  Principles of cell biology inherent in tissue ...        2 hours.
# 1591  Principles of cell biology inherent in tissue ...        2 hours.
# 1592  Principles of cell biology inherent in tissue ...        2 hours.
# 1593  Introduction to signals and linear systems wit...        3 hours.
# 1594  Using analytical and computational tools from ...        3 hours.
# 1595  Special project or reading activity. May be re...   1 TO 4 hours.
# 1596  Experiments involving the modeling and measure...        2 hours.
# 1597  Experiments involving the modeling and measure...        2 hours.
# 1598  Experiments involving the modeling and measure...        2 hours.
# 1599  Experiments involving design of bioreactors an...        3 hours.
# 1600  Experiments involving design of bioreactors an...        3 hours.
# 1601  Fundamental and applied statistics, including ...        3 hours.
# 1602  Fundamentals of fluid dynamics and mass transp...        3 hours.
# 1603  Special project or reading activity. May be re...   1 TO 4 hours.
# 1604  Engineering aspects of the detection, acquisit...        3 hours.
# 1605  Laboratory to accompany BIOE 414. Use of senso...        2 hours.
# 1606  Laboratory to accompany BIOE 414. Use of senso...        2 hours.
# 1607  Laboratory to accompany BIOE 414. Use of senso...        2 hours.
# 1608  Laboratory to accompany BIOE 414. Use of senso...        2 hours.
# 1609  Laboratory to accompany BIOE 414. Use of senso...        2 hours.
# 1610                      Same as ECE 416. See ECE 416.        3 hours.
# 1611                      Same as ECE 416. See ECE 416.        3 hours.
# 1612  Systems engineering approach to modeling physi...        3 hours.
# 1613  Capstone bioengineering design activity to dev...        2 hours.
# 1614  Continuation of BIOE 435. Design teams finaliz...        2 hours.
# 1615  An elective course for undergraduate students ...        3 hours.
# 1616                        Same as ME 481. See ME 481.   3 OR 4 hours.
# 1617                        Same as ME 481. See ME 481.   3 OR 4 hours.
# 1618  Biomedical image data often come in extreme nu...   3 OR 4 hours.
# 1619  Biomedical image data often come in extreme nu...   3 OR 4 hours.
# 1620  Covers basic concepts, methodology and algorit...   3 OR 4 hours.
# 1621  Covers basic concepts, methodology and algorit...   3 OR 4 hours.
# 1622  Stem Cell Bioengineering will provide a founda...   3 OR 4 hours.
# 1623  Special project or reading activity. 1 to 4 un...   1 TO 4 hours.
# 1624  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1625  Limited in general to seniors in the curriculu...   1 TO 5 hours.
# 1626  Lecture surveying a broad range of Bioengineer...        1 hours.
# 1627  Guest topics will vary, but will typically cov...        1 hours.
# 1628  Guest topics will vary, but will typically cov...        1 hours.
# 1629  With special focus on medical imaging, learn a...        4 hours.
# 1630  With special focus on medical imaging, learn a...        4 hours.
# 1631  Tools, concepts, and analytical frameworks tha...        4 hours.
# 1632  Tools, concepts, and analytical frameworks tha...        4 hours.
# 1633  Students in the Master of Engineering (M.Eng.)...        3 hours.
# 1634  Students in the Master of Engineering (M.Eng.)...        3 hours.
# 1635  Exposes students to a broad treatment of the m...        4 hours.
# 1636  This journal-club style course will expose stu...        1 hours.
# 1637  Special project or reading activity. May be re...   1 TO 8 hours.
# 1638  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1639  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1640  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1641  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1642  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1643  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1644  Bioengineering graduate thesis research. Appro...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 1586                                                NaN               NaN
# 1587               Prerequisite: BIOE 120. Majors only.               NaN
# 1588  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1589  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1590  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1591  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1592  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1593  Prerequisite: CS 101 or CS 124, PHYS 212, and ...               NaN
# 1594      Prerequisite: CS 101 or CS 124, and MATH 231.               NaN
# 1595  May be repeated in the same or separate terms ...               NaN
# 1596  Prerequisite: Concurrent enrollment in BIOE 30...               NaN
# 1597  Prerequisite: Concurrent enrollment in BIOE 30...               NaN
# 1598  Prerequisite: Concurrent enrollment in BIOE 30...               NaN
# 1599  Prerequisite: BIOE 202. Departmental approval ...               NaN
# 1600  Prerequisite: BIOE 202. Departmental approval ...               NaN
# 1601  Credit is not given towards graduation for bot...               NaN
# 1602  Credit is not given for both BIOE 360 and any ...               NaN
# 1603  May be repeated up to 8 hours in a term to a m...               NaN
# 1604  Same as ECE 414. 3 undergraduate hours. 3 grad...               NaN
# 1605  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1606  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1607  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1608  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1609  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1610                      Same as ECE 416. See ECE 416.               NaN
# 1611                      Same as ECE 416. See ECE 416.               NaN
# 1612  3 undergraduate hours. No graduate credit. Cre...               NaN
# 1613  2 undergraduate hours. No graduate credit. Pre...               NaN
# 1614  2 undergraduate hours. No graduate credit. Pre...               NaN
# 1615  3 undergraduate hours. No graduate credit. App...               NaN
# 1616                        Same as ME 481. See ME 481.               NaN
# 1617                        Same as ME 481. See ME 481.               NaN
# 1618  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 1619  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 1620  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 1621  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 1622  3 undergraduate hours. 4 graduate hours. Prere...               NaN
# 1623  1 to 4 undergraduate hours. 1 to 4 graduate ho...               NaN
# 1624  1 to 4 undergraduate hours. 1 to 4 graduate ho...               NaN
# 1625  1 to 5 undergraduate hours. No graduate credit...               NaN
# 1626  0 or 1 graduate hours. No professional credit....               NaN
# 1627  1 graduate hour. No professional credit. Appro...               NaN
# 1628  1 graduate hour. No professional credit. Appro...               NaN
# 1629  4 graduate hours. No professional credit. Prer...               NaN
# 1630  4 graduate hours. No professional credit. Prer...               NaN
# 1631  4 graduate hours. No professional credit. Prer...               NaN
# 1632  4 graduate hours. No professional credit. Prer...               NaN
# 1633  3 graduate hours. No professional credit. May ...               NaN
# 1634  3 graduate hours. No professional credit. May ...               NaN
# 1635  4 graduate hours. No professional credit. Prer...               NaN
# 1636  1 graduate hour. No professional credit. Appro...               NaN
# 1637  May be repeated. Prerequisite: Approved writte...               NaN
# 1638  1 to 4 graduate hours. No professional credit....               NaN
# 1639  1 to 4 graduate hours. No professional credit....               NaN
# 1640  1 to 4 graduate hours. No professional credit....               NaN
# 1641  1 to 4 graduate hours. No professional credit....               NaN
# 1642  1 to 4 graduate hours. No professional credit....               NaN
# 1643  1 to 4 graduate hours. No professional credit....               NaN
# 1644    Approved for S/U grading only. May be repeated.               NaN
#
#       ... Section Status           Enrollment Status                   Type  \
# 1586  ...              A           Open (Restricted)                Lecture
# 1587  ...              A           Open (Restricted)                Lecture
# 1588  ...              A                      Closed             Laboratory
# 1589  ...              A                      Closed             Laboratory
# 1590  ...              A                        Open             Laboratory
# 1591  ...              A                      Closed             Laboratory
# 1592  ...              A           Open (Restricted)                Lecture
# 1593  ...              A                        Open     Lecture-Discussion
# 1594  ...              A                        Open                Lecture
# 1595  ...              A           Open (Restricted)      Independent Study
# 1596  ...              A                        Open             Laboratory
# 1597  ...              A                        Open             Laboratory
# 1598  ...              A           Open (Restricted)     Lecture-Discussion
# 1599  ...              A           Open (Restricted)             Laboratory
# 1600  ...              A           Open (Restricted)             Laboratory
# 1601  ...              A           Open (Restricted)                Lecture
# 1602  ...              A           Open (Restricted)                Lecture
# 1603  ...              A           Open (Restricted)      Independent Study
# 1604  ...              A               CrossListOpen  Discussion/Recitation
# 1605  ...              A                      Closed             Laboratory
# 1606  ...              A                      Closed             Laboratory
# 1607  ...              A               CrossListOpen             Laboratory
# 1608  ...              A               CrossListOpen             Laboratory
# 1609  ...              A  CrossListOpen (Restricted)                Lecture
# 1610  ...              A               CrossListOpen                Lecture
# 1611  ...              A                      Closed         Online Lecture
# 1612  ...              A                      Closed                Lecture
# 1613  ...              A           Open (Restricted)     Lecture-Discussion
# 1614  ...              A                      Closed                 Online
# 1615  ...              A  CrossListOpen (Restricted)     Lecture-Discussion
# 1616  ...              A                      Closed     Lecture-Discussion
# 1617  ...              A                      Closed     Lecture-Discussion
# 1618  ...              A               CrossListOpen                Lecture
# 1619  ...              A  CrossListOpen (Restricted)                Lecture
# 1620  ...              A               CrossListOpen                Lecture
# 1621  ...              A  CrossListOpen (Restricted)                Lecture
# 1622  ...              A  CrossListOpen (Restricted)                Lecture
# 1623  ...              A           Open (Restricted)      Independent Study
# 1624  ...              A                      Closed                Lecture
# 1625  ...              A                      Closed      Independent Study
# 1626  ...              A           Open (Restricted)                Lecture
# 1627  ...              A           Open (Restricted)                 Online
# 1628  ...              A           Open (Restricted)     Lecture-Discussion
# 1629  ...              A           Open (Restricted)     Lecture-Discussion
# 1630  ...              A           Open (Restricted)                 Online
# 1631  ...              A           Open (Restricted)     Lecture-Discussion
# 1632  ...              A           Open (Restricted)                 Online
# 1633  ...              A           Open (Restricted)                 Online
# 1634  ...              A           Open (Restricted)                Lecture
# 1635  ...              A           Open (Restricted)                Lecture
# 1636  ...              A           Open (Restricted)     Lecture-Discussion
# 1637  ...              A           Open (Restricted)      Independent Study
# 1638  ...              A           Open (Restricted)                Lecture
# 1639  ...              A                      Closed                Lecture
# 1640  ...              A                      Closed     Lecture-Discussion
# 1641  ...              A           Open (Restricted)                 Online
# 1642  ...              A  CrossListOpen (Restricted)                Lecture
# 1643  ...              A           Open (Restricted)                 Online
# 1644  ...              A           Open (Restricted)      Independent Study
#
#      Type Code Start Time  End Time Days of Week  Room  \
# 1586       LEC   11:00 AM  11:50 AM           MW    35
# 1587       LEC   12:00 PM  12:50 PM            W  2101
# 1588       LAB   12:00 PM  03:50 PM            T  3109
# 1589       LAB   12:00 PM  03:50 PM            R  3109
# 1590       LAB   04:00 PM  07:50 PM            T  3109
# 1591       LAB   11:00 AM  02:50 PM            M  3109
# 1592       LEC   12:00 PM  12:50 PM            F  2310
# 1593       LCD   10:00 AM  10:50 AM          MWF  4025
# 1594       LEC   09:30 AM  10:50 AM           TR  2310
# 1595       IND   ARRANGED       NaN          NaN   NaN
# 1596       LAB   12:00 PM  02:50 PM            T   215
# 1597       LAB   02:00 PM  04:50 PM            R   215
# 1598       LCD   01:00 PM  01:50 PM            M  1306
# 1599       LAB   09:30 AM  11:20 AM           TR  3109
# 1600       LAB   09:30 AM  10:20 AM            M  3109
# 1601       LEC   09:30 AM  10:50 AM           TR  1302
# 1602       LEC   09:00 AM  09:50 AM          MWF  1302
# 1603       IND   ARRANGED       NaN          NaN   NaN
# 1604       DIS   11:00 AM  11:50 AM          MWF  3025
# 1605       LAB   01:00 PM  03:50 PM            M   201
# 1606       LAB   12:00 PM  02:50 PM            W   201
# 1607       LAB   03:00 PM  05:50 PM            W   201
# 1608       LAB   04:00 PM  06:50 PM            M   201
# 1609       LEC   12:00 PM  12:50 PM            M  1306
# 1610       LEC   09:00 AM  09:50 AM          MWF  2017
# 1611       OLC   09:00 AM  09:50 AM          MWF   NaN
# 1612       LEC   11:00 AM  11:50 AM          MWF   119
# 1613       LCD   08:00 AM  09:20 AM           TR  2233
# 1614       ONL   ARRANGED       NaN          NaN   NaN
# 1615       LCD   05:00 PM  06:20 PM           TR  1306
# 1616       LCD   01:00 PM  01:50 PM          MWF  3100
# 1617       LCD   01:00 PM  01:50 PM          MWF  3100
# 1618       LEC   02:00 PM  03:20 PM           TR   214
# 1619       LEC   02:00 PM  03:20 PM           TR   214
# 1620       LEC   12:30 PM  01:50 PM           TR  2101
# 1621       LEC   12:30 PM  01:50 PM           TR  2101
# 1622       LEC   03:30 PM  04:50 PM           TR  1302
# 1623        N1   ARRANGED       NaN          NaN   NaN
# 1624       LEC   09:30 AM  10:50 AM           TR  2101
# 1625       IND   ARRANGED       NaN          NaN   NaN
# 1626       LEC   11:30 AM  12:20 PM            T  2310
# 1627       ONL   ARRANGED       NaN          NaN   NaN
# 1628       LCD   09:00 AM  10:50 AM            F   214
# 1629       LCD   09:30 AM  10:50 AM           MW    18
# 1630       ONL   ARRANGED       NaN          NaN   NaN
# 1631       LCD   11:00 AM  12:20 PM           TR  2101
# 1632       ONL   ARRANGED       NaN          NaN   NaN
# 1633       ONL   ARRANGED       NaN          NaN   NaN
# 1634       LEC   08:00 AM  09:20 AM           TR   NaN
# 1635       LEC   03:00 PM  04:50 PM           MW   320
# 1636       LCD   10:00 AM  10:50 AM            F  2036
# 1637       IND   ARRANGED       NaN          NaN   NaN
# 1638        L1   ARRANGED       NaN          NaN   NaN
# 1639       LEC   03:30 PM  04:50 PM           TR  1302
# 1640       LCD   05:00 PM  06:20 PM           TR  1306
# 1641       ONL   ARRANGED       NaN          NaN   NaN
# 1642       LEC   09:30 AM  10:50 AM           TR  2101
# 1643       ONL   ARRANGED       NaN          NaN   NaN
# 1644       IND   ARRANGED       NaN          NaN   NaN
#
#                             Building                     Instructors
# 1586   Campus Instructional Facility                 Best-Popescu, C
# 1587              Everitt Laboratory                    Vozenilek, J
# 1588              Everitt Laboratory  Gaj, T;Perez Pinera, P;Sirk, S
# 1589              Everitt Laboratory  Gaj, T;Perez Pinera, P;Sirk, S
# 1590              Everitt Laboratory  Gaj, T;Perez Pinera, P;Sirk, S
# 1591              Everitt Laboratory  Gaj, T;Perez Pinera, P;Sirk, S
# 1592              Everitt Laboratory  Gaj, T;Perez Pinera, P;Sirk, S
# 1593   Campus Instructional Facility                      Abraham, I
# 1594              Everitt Laboratory                       Insana, M
# 1595                             NaN                             NaN
# 1596              Everitt Laboratory                    Cvetkovic, C
# 1597              Everitt Laboratory                    Cvetkovic, C
# 1598              Everitt Laboratory                    Cvetkovic, C
# 1599              Everitt Laboratory                    Cvetkovic, C
# 1600              Everitt Laboratory                    Cvetkovic, C
# 1601              Everitt Laboratory                       Maslov, S
# 1602              Everitt Laboratory                      Leggett, S
# 1603                             NaN                             NaN
# 1604   Campus Instructional Facility                   Irudayaraj, J
# 1605              Everitt Laboratory                         Reck, R
# 1606              Everitt Laboratory                         Reck, R
# 1607              Everitt Laboratory                         Reck, R
# 1608              Everitt Laboratory                         Reck, R
# 1609              Everitt Laboratory                         Reck, R
# 1610  Electrical & Computer Eng Bldg       Cunningham, B;Shepherd, S
# 1611                             NaN                   Cunningham, B
# 1612     Materials Science & Eng Bld                       Monroy, G
# 1613              Everitt Laboratory                      Golecki, H
# 1614                             NaN                      Golecki, H
# 1615              Everitt Laboratory                          Nie, S
# 1616        Sidney Lu Mech Engr Bldg                        Kersh, M
# 1617        Sidney Lu Mech Engr Bldg                        Kersh, M
# 1618               Ceramics Building                       Brooks, F
# 1619               Ceramics Building                       Brooks, F
# 1620              Everitt Laboratory                          Lam, F
# 1621              Everitt Laboratory                          Lam, F
# 1622              Everitt Laboratory                    Underhill, G
# 1623                             NaN                             NaN
# 1624              Everitt Laboratory                         Amos, J
# 1625                             NaN                             NaN
# 1626              Everitt Laboratory                   Irudayaraj, J
# 1627                             NaN                 Best-Popescu, C
# 1628               Ceramics Building                 Best-Popescu, C
# 1629   Campus Instructional Facility                Campos Coiado, O
# 1630                             NaN                Campos Coiado, O
# 1631              Everitt Laboratory                      Bradley, J
# 1632                             NaN                      Bradley, J
# 1633                             NaN              Amos, J;Bradley, J
# 1634                             NaN              Amos, J;Bradley, J
# 1635                    Mumford Hall                       Brooks, F
# 1636   Campus Instructional Facility                    Anastasio, M
# 1637                             NaN                             NaN
# 1638                             NaN                   Irudayaraj, J
# 1639              Everitt Laboratory                    Underhill, G
# 1640              Everitt Laboratory                          Nie, S
# 1641                             NaN                          Nie, S
# 1642              Everitt Laboratory                         Amos, J
# 1643                             NaN                         Amos, J
# 1644                             NaN                             NaN
#
# [59 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.2:
#
# Select **five random courses** from your major, using `mydf` and pandas functions:

# %%
mydf.sample(n=5)
# Out:
#       Year    Term YearTerm Subject  Number  \
# 1641  2023  Spring  2023-sp    BIOE     598
# 1595  2023  Spring  2023-sp    BIOE     297
# 1598  2023  Spring  2023-sp    BIOE     303
# 1605  2023  Spring  2023-sp    BIOE     415
# 1589  2023  Spring  2023-sp    BIOE     202
#
#                                    Name  \
# 1641                     Special Topics
# 1595                   Individual Study
# 1598        Quantitative Physiology Lab
# 1605     Biomedical Instrumentation Lab
# 1589  Cell &amp; Tissue Engineering Lab
#
#                                             Description   Credit Hours  \
# 1641  Subject offerings of new and developing areas ...  1 TO 4 hours.
# 1595  Special project or reading activity. May be re...  1 TO 4 hours.
# 1598  Experiments involving the modeling and measure...       2 hours.
# 1605  Laboratory to accompany BIOE 414. Use of senso...       2 hours.
# 1589  Principles of cell biology inherent in tissue ...       2 hours.
#
#                                            Section Info Degree Attributes  \
# 1641  1 to 4 graduate hours. No professional credit....               NaN
# 1595  May be repeated in the same or separate terms ...               NaN
# 1598  Prerequisite: Concurrent enrollment in BIOE 30...               NaN
# 1605  Same as ECE 415. 2 undergraduate hours. 2 grad...               NaN
# 1589  Prerequisite: MCB 150, and credit or concurren...               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 1641  ...              A  Open (Restricted)              Online       ONL
# 1595  ...              A  Open (Restricted)   Independent Study       IND
# 1598  ...              A  Open (Restricted)  Lecture-Discussion       LCD
# 1605  ...              A             Closed          Laboratory       LAB
# 1589  ...              A             Closed          Laboratory       LAB
#
#      Start Time  End Time Days of Week  Room            Building  \
# 1641   ARRANGED       NaN          NaN   NaN                 NaN
# 1595   ARRANGED       NaN          NaN   NaN                 NaN
# 1598   01:00 PM  01:50 PM            M  1306  Everitt Laboratory
# 1605   01:00 PM  03:50 PM            M   201  Everitt Laboratory
# 1589   12:00 PM  03:50 PM            R  3109  Everitt Laboratory
#
#                          Instructors
# 1641                          Nie, S
# 1595                             NaN
# 1598                    Cvetkovic, C
# 1605                         Reck, R
# 1589  Gaj, T;Perez Pinera, P;Sirk, S
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.3:
#
# Select **the seven lowest numbered courses** from your major:

# %%
mydf.nsmallest(7,"Number")
# Out:
#       Year    Term YearTerm Subject  Number  \
# 1586  2023  Spring  2023-sp    BIOE     120
# 1587  2023  Spring  2023-sp    BIOE     200
# 1588  2023  Spring  2023-sp    BIOE     202
# 1589  2023  Spring  2023-sp    BIOE     202
# 1590  2023  Spring  2023-sp    BIOE     202
# 1591  2023  Spring  2023-sp    BIOE     202
# 1592  2023  Spring  2023-sp    BIOE     202
#
#                                    Name  \
# 1586     Introduction to Bioengineering
# 1587    Bioengineering Career Immersion
# 1588  Cell &amp; Tissue Engineering Lab
# 1589  Cell &amp; Tissue Engineering Lab
# 1590  Cell &amp; Tissue Engineering Lab
# 1591  Cell &amp; Tissue Engineering Lab
# 1592  Cell &amp; Tissue Engineering Lab
#
#                                             Description Credit Hours  \
# 1586  Lectures and discussions of recent trends in b...     1 hours.
# 1587  This course provides exposure to Bioengineerin...     1 hours.
# 1588  Principles of cell biology inherent in tissue ...     2 hours.
# 1589  Principles of cell biology inherent in tissue ...     2 hours.
# 1590  Principles of cell biology inherent in tissue ...     2 hours.
# 1591  Principles of cell biology inherent in tissue ...     2 hours.
# 1592  Principles of cell biology inherent in tissue ...     2 hours.
#
#                                            Section Info Degree Attributes  \
# 1586                                                NaN               NaN
# 1587               Prerequisite: BIOE 120. Majors only.               NaN
# 1588  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1589  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1590  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1591  Prerequisite: MCB 150, and credit or concurren...               NaN
# 1592  Prerequisite: MCB 150, and credit or concurren...               NaN
#
#       ... Section Status  Enrollment Status        Type Type Code Start Time  \
# 1586  ...              A  Open (Restricted)     Lecture       LEC   11:00 AM
# 1587  ...              A  Open (Restricted)     Lecture       LEC   12:00 PM
# 1588  ...              A             Closed  Laboratory       LAB   12:00 PM
# 1589  ...              A             Closed  Laboratory       LAB   12:00 PM
# 1590  ...              A               Open  Laboratory       LAB   04:00 PM
# 1591  ...              A             Closed  Laboratory       LAB   11:00 AM
# 1592  ...              A  Open (Restricted)     Lecture       LEC   12:00 PM
#
#       End Time Days of Week  Room                       Building  \
# 1586  11:50 AM           MW    35  Campus Instructional Facility
# 1587  12:50 PM            W  2101             Everitt Laboratory
# 1588  03:50 PM            T  3109             Everitt Laboratory
# 1589  03:50 PM            R  3109             Everitt Laboratory
# 1590  07:50 PM            T  3109             Everitt Laboratory
# 1591  02:50 PM            M  3109             Everitt Laboratory
# 1592  12:50 PM            F  2310             Everitt Laboratory
#
#                          Instructors
# 1586                 Best-Popescu, C
# 1587                    Vozenilek, J
# 1588  Gaj, T;Perez Pinera, P;Sirk, S
# 1589  Gaj, T;Perez Pinera, P;Sirk, S
# 1590  Gaj, T;Perez Pinera, P;Sirk, S
# 1591  Gaj, T;Perez Pinera, P;Sirk, S
# 1592  Gaj, T;Perez Pinera, P;Sirk, S
#
# [7 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.4:
#
# Select **the nine highest numbered courses** from your major:

# %%
mydf.nlargest(9,"Number")
# Out:
#       Year    Term YearTerm Subject  Number  \
# 1644  2023  Spring  2023-sp    BIOE     599
# 1638  2023  Spring  2023-sp    BIOE     598
# 1639  2023  Spring  2023-sp    BIOE     598
# 1640  2023  Spring  2023-sp    BIOE     598
# 1641  2023  Spring  2023-sp    BIOE     598
# 1642  2023  Spring  2023-sp    BIOE     598
# 1643  2023  Spring  2023-sp    BIOE     598
# 1637  2023  Spring  2023-sp    BIOE     597
# 1636  2023  Spring  2023-sp    BIOE     588
#
#                                                    Name  \
# 1644                                    Thesis Research
# 1638                                     Special Topics
# 1639                                     Special Topics
# 1640                                     Special Topics
# 1641                                     Special Topics
# 1642                                     Special Topics
# 1643                                     Special Topics
# 1637                                   Individual Study
# 1636  Biomedical Image Computing Capstone Project Li...
#
#                                             Description    Credit Hours  \
# 1644  Bioengineering graduate thesis research. Appro...  0 TO 16 hours.
# 1638  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1639  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1640  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1641  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1642  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1643  Subject offerings of new and developing areas ...   1 TO 4 hours.
# 1637  Special project or reading activity. May be re...   1 TO 8 hours.
# 1636  This journal-club style course will expose stu...        1 hours.
#
#                                            Section Info Degree Attributes  \
# 1644    Approved for S/U grading only. May be repeated.               NaN
# 1638  1 to 4 graduate hours. No professional credit....               NaN
# 1639  1 to 4 graduate hours. No professional credit....               NaN
# 1640  1 to 4 graduate hours. No professional credit....               NaN
# 1641  1 to 4 graduate hours. No professional credit....               NaN
# 1642  1 to 4 graduate hours. No professional credit....               NaN
# 1643  1 to 4 graduate hours. No professional credit....               NaN
# 1637  May be repeated. Prerequisite: Approved writte...               NaN
# 1636  1 graduate hour. No professional credit. Appro...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 1644  ...              A           Open (Restricted)   Independent Study
# 1638  ...              A           Open (Restricted)             Lecture
# 1639  ...              A                      Closed             Lecture
# 1640  ...              A                      Closed  Lecture-Discussion
# 1641  ...              A           Open (Restricted)              Online
# 1642  ...              A  CrossListOpen (Restricted)             Lecture
# 1643  ...              A           Open (Restricted)              Online
# 1637  ...              A           Open (Restricted)   Independent Study
# 1636  ...              A           Open (Restricted)  Lecture-Discussion
#
#      Type Code Start Time  End Time Days of Week  Room  \
# 1644       IND   ARRANGED       NaN          NaN   NaN
# 1638        L1   ARRANGED       NaN          NaN   NaN
# 1639       LEC   03:30 PM  04:50 PM           TR  1302
# 1640       LCD   05:00 PM  06:20 PM           TR  1306
# 1641       ONL   ARRANGED       NaN          NaN   NaN
# 1642       LEC   09:30 AM  10:50 AM           TR  2101
# 1643       ONL   ARRANGED       NaN          NaN   NaN
# 1637       IND   ARRANGED       NaN          NaN   NaN
# 1636       LCD   10:00 AM  10:50 AM            F  2036
#
#                            Building    Instructors
# 1644                            NaN            NaN
# 1638                            NaN  Irudayaraj, J
# 1639             Everitt Laboratory   Underhill, G
# 1640             Everitt Laboratory         Nie, S
# 1641                            NaN         Nie, S
# 1642             Everitt Laboratory        Amos, J
# 1643                            NaN        Amos, J
# 1637                            NaN            NaN
# 1636  Campus Instructional Facility   Anastasio, M
#
# [9 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.5:
#
# Select **a random sample of 10% of the courses** from your major:

# %%
mydf.sample(frac=0.1)
# Out:
#       Year    Term YearTerm Subject  Number  \
# 1636  2023  Spring  2023-sp    BIOE     588
# 1598  2023  Spring  2023-sp    BIOE     303
# 1603  2023  Spring  2023-sp    BIOE     397
# 1642  2023  Spring  2023-sp    BIOE     598
# 1612  2023  Spring  2023-sp    BIOE     420
# 1625  2023  Spring  2023-sp    BIOE     499
#
#                                                    Name  \
# 1636  Biomedical Image Computing Capstone Project Li...
# 1598                        Quantitative Physiology Lab
# 1603                                   Individual Study
# 1642                                     Special Topics
# 1612                          Intro Bio Control Systems
# 1625                                      Senior Thesis
#
#                                             Description   Credit Hours  \
# 1636  This journal-club style course will expose stu...       1 hours.
# 1598  Experiments involving the modeling and measure...       2 hours.
# 1603  Special project or reading activity. May be re...  1 TO 4 hours.
# 1642  Subject offerings of new and developing areas ...  1 TO 4 hours.
# 1612  Systems engineering approach to modeling physi...       3 hours.
# 1625  Limited in general to seniors in the curriculu...  1 TO 5 hours.
#
#                                            Section Info Degree Attributes  \
# 1636  1 graduate hour. No professional credit. Appro...               NaN
# 1598  Prerequisite: Concurrent enrollment in BIOE 30...               NaN
# 1603  May be repeated up to 8 hours in a term to a m...               NaN
# 1642  1 to 4 graduate hours. No professional credit....               NaN
# 1612  3 undergraduate hours. No graduate credit. Cre...               NaN
# 1625  1 to 5 undergraduate hours. No graduate credit...               NaN
#
#       ... Section Status           Enrollment Status                Type  \
# 1636  ...              A           Open (Restricted)  Lecture-Discussion
# 1598  ...              A           Open (Restricted)  Lecture-Discussion
# 1603  ...              A           Open (Restricted)   Independent Study
# 1642  ...              A  CrossListOpen (Restricted)             Lecture
# 1612  ...              A                      Closed             Lecture
# 1625  ...              A                      Closed   Independent Study
#
#      Type Code Start Time  End Time Days of Week  Room  \
# 1636       LCD   10:00 AM  10:50 AM            F  2036
# 1598       LCD   01:00 PM  01:50 PM            M  1306
# 1603       IND   ARRANGED       NaN          NaN   NaN
# 1642       LEC   09:30 AM  10:50 AM           TR  2101
# 1612       LEC   11:00 AM  11:50 AM          MWF   119
# 1625       IND   ARRANGED       NaN          NaN   NaN
#
#                            Building   Instructors
# 1636  Campus Instructional Facility  Anastasio, M
# 1598             Everitt Laboratory  Cvetkovic, C
# 1603                            NaN           NaN
# 1642             Everitt Laboratory       Amos, J
# 1612    Materials Science & Eng Bld     Monroy, G
# 1625                            NaN           NaN
#
# [6 rows x 27 columns]

# %% [markdown]
# ### ✔️ Checkpoint ✔️
#
# There is no test cases for Part 4 (since everyone has different majors), but go double check your work!  There's just one section left to go! :)

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 5: Growth of the IS major
#
# The IS major is still a new relatively new major here at UIUC. The final puzzle is for you to analyze how much the IS major has grown since 2019.

# %% [markdown]
# ### Puzzle 5.1: Loading the Course Catalog Dataset from 2019
#
# Using the name `df2019` instead of `df`, load the "Fall 2019 Course Catalog Dataset" that can be found at the following URL:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv
# ```

# %%
df2019 = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv")
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %% [markdown]
# ### Puzzle 5.2: Data Science Analysis
#
# In the following cells,
# - Select only the rows from the `IS` subject from the `df2019` dataset,
# - Select only the rows from the `IS` subject from the `df` dataset (this contains the 2023 data),
# - Complete the reflection question below (Puzzle 5.3).  Feel free to write more code to answer it.

# %%
df[df["Subject"]== "IS"]
# Out:
#       Year    Term YearTerm Subject  Number  \
# 6045  2023  Spring  2023-sp      IS     100
# 6046  2023  Spring  2023-sp      IS     101
# 6047  2023  Spring  2023-sp      IS     101
# 6048  2023  Spring  2023-sp      IS     101
# 6049  2023  Spring  2023-sp      IS     101
# ...    ...     ...      ...     ...     ...
# 6294  2023  Spring  2023-sp      IS     597
# 6295  2023  Spring  2023-sp      IS     597
# 6296  2023  Spring  2023-sp      IS     597
# 6297  2023  Spring  2023-sp      IS     597
# 6298  2023  Spring  2023-sp      IS     599
#
#                                                    Name  \
# 6045   Exploring the iSchool with a Human-Centered Lens
# 6046               Introduction to Information Sciences
# 6047               Introduction to Information Sciences
# 6048               Introduction to Information Sciences
# 6049               Introduction to Information Sciences
# ...                                                 ...
# 6294  Advanced Topics in Data Analytics &amp; Data S...
# 6295  Advanced Topics in Data Analytics &amp; Data S...
# 6296  Advanced Topics in Data Analytics &amp; Data S...
# 6297  Advanced Topics in Data Analytics &amp; Data S...
# 6298                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 6045  This course introduces students to the School ...        1 hours.
# 6046  This course provides an introduction to the fi...        3 hours.
# 6047  This course provides an introduction to the fi...        3 hours.
# 6048  This course provides an introduction to the fi...        3 hours.
# 6049  This course provides an introduction to the fi...        3 hours.
# ...                                                 ...             ...
# 6294  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6295  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6296  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6297  Variety of newly developed and advanced topics...   2 OR 4 hours.
# 6298  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 6045  Prerequisite: Restricted to Majors Only; First...
# 6046                                                NaN
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# ...                                                 ...
# 6294  2 or 4 graduate hours. No professional credit....
# 6295  2 or 4 graduate hours. No professional credit....
# 6296  2 or 4 graduate hours. No professional credit....
# 6297  2 or 4 graduate hours. No professional credit....
# 6298  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes  ... Section Status  \
# 6045                                 NaN  ...              A
# 6046  Social & Beh Sci - Soc Sci course.  ...              A
# 6047  Social & Beh Sci - Soc Sci course.  ...              A
# 6048  Social & Beh Sci - Soc Sci course.  ...              A
# 6049  Social & Beh Sci - Soc Sci course.  ...              A
# ...                                  ...  ...            ...
# 6294                                 NaN  ...              A
# 6295                                 NaN  ...              A
# 6296                                 NaN  ...              A
# 6297                                 NaN  ...              A
# 6298                                 NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 6045  Open (Restricted)     Lecture-Discussion       LCD   04:00 PM  04:50 PM
# 6046             Closed  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6047               Open  Discussion/Recitation       DIS   11:00 AM  12:20 PM
# 6048             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# 6049             Closed  Discussion/Recitation       DIS   12:30 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 6294  Open (Restricted)                 Online        E3   01:00 PM  03:50 PM
# 6295  Open (Restricted)     Lecture-Discussion        S1   09:00 AM  11:50 AM
# 6296  Open (Restricted)     Lecture-Discussion       LCD   09:00 AM  11:50 AM
# 6297  Open (Restricted)                 Online        E2   02:00 PM  03:55 PM
# 6298  Open (Restricted)      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week Room                        Building            Instructors
# 6045            W  126  Grad Sch of Lib & Info Science              Newell, M
# 6046            R  12A  Grad Sch of Lib & Info Science              Pintar, J
# 6047            R   53  Grad Sch of Lib & Info Science              Pintar, J
# 6048            R  126  Grad Sch of Lib & Info Science              Pintar, J
# 6049            R  315                    Gregory Hall              Pintar, J
# ...           ...  ...                             ...                    ...
# 6294            M  NaN                             NaN             LeBlanc, Z
# 6295            F  131  Grad Sch of Lib & Info Science              Weible, J
# 6296            W  126  Grad Sch of Lib & Info Science              Weible, J
# 6297            T  NaN                             NaN  Hsiao, T;Schneider, J
# 6298          NaN  NaN                             NaN                    NaN
#
# [254 rows x 27 columns]

# %%
df2019[df2019["Subject"]== "IS"]
# Out:
#       Year  Term YearTerm Subject  Number  \
# 4843  2019  Fall  2019-fa      IS     107
# 4844  2019  Fall  2019-fa      IS     199
# 4845  2019  Fall  2019-fa      IS     202
# 4846  2019  Fall  2019-fa      IS     310
# 4847  2019  Fall  2019-fa      IS     351
# ...    ...   ...      ...     ...     ...
# 4930  2019  Fall  2019-fa      IS     591
# 4931  2019  Fall  2019-fa      IS     592
# 4932  2019  Fall  2019-fa      IS     593
# 4933  2019  Fall  2019-fa      IS     594
# 4934  2019  Fall  2019-fa      IS     599
#
#                                              Name  \
# 4843                       Data Science Discovery
# 4844                   Undergraduate Open Seminar
# 4845                     Social Aspects Info Tech
# 4846                  Computing in the Humanities
# 4847  The Design of Usable Information Interfaces
# ...                                           ...
# 4930                                    Practicum
# 4931                            Independent Study
# 4932                                  CAS Project
# 4933                Information Sciences Practice
# 4934                              Thesis Research
#
#                                             Description    Credit Hours  \
# 4843          Same as CS 107 and STAT 107. See STAT 107        4 hours.
# 4844       Undergraduate Open Seminar. May be repeated.   1 TO 5 hours.
# 4845       Same as INFO 202 and MACS 202. See INFO 202.        3 hours.
# 4846  Explores use and application of technology to ...        3 hours.
# 4847  Examines issues of Human Computer Interaction ...        3 hours.
# ...                                                 ...             ...
# 4930  Supervised field experience of professional-le...        2 hours.
# 4931  Permits the intermediate or advanced student o...   2 TO 4 hours.
# 4932  Individual study of a problem in library and i...   0 TO 8 hours.
# 4933  Full-time or part-time practice of of any info...        0 hours.
# 4934  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 4843          Same as CS 107 and STAT 107. See STAT 107
# 4844                                                NaN
# 4845       Same as INFO 202 and MACS 202. See INFO 202.
# 4846                                                NaN
# 4847                  Prerequisite: Sophomore standing.
# ...                                                 ...
# 4930  2 graduate hours. No professional credit. Appr...
# 4931  2 to 4 graduate hours. No professional credit....
# 4932  0 to 8 graduate hours. No professional credit....
# 4933  0 graduate hours. No professional credit. Appr...
# 4934  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes
# 4843    Quantitative Reasoning I course.
# 4844                                 NaN
# 4845  Social & Beh Sci - Soc Sci course.
# 4846                                 NaN
# 4847                                 NaN
# ...                                  ...
# 4930                                 NaN
# 4931                                 NaN
# 4932                                 NaN
# 4933                                 NaN
# 4934                                 NaN
#
# [92 rows x 10 columns]

# %%
# Feel free to add more code cells if needed by hovering over the area below the cell and pressing "+ Code"!

# %%
254-92
# Out:
# 162

# %% [markdown]
# ### Puzzle 5.3: Reflection on the Growth of Information Science
#
# In the follow cell, write **at least one complete sentence explaining what you found** related to the growth of the IS program.  In your answer, **use actual data** (ex: by how much did it grow?)

# %% [markdown]
# By analyzing the number of rows in both the 2019 and current datasets, I found that the program grew by 162 courses!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission

# %% [markdown]
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
