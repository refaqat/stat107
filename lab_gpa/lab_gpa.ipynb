# %% [markdown]
# # Welcome to Lab: GPA 🎓
#
# In this lab, you'll explore the GPA dataset again to find out more about the courses at Illinois!
#
# Fun fact: the dataset you're using in this lab is the same dataset that Professor Wade uses to make the GPA visualizations! :)  Check this out here if you haven't seen it already: [https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/](https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/)
#
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Kim"
ca1_name = "Mia"
ca2_name = "Jai"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# Question of the Day (QOTD) to Ask Your Group: "Who's your favorite music artist?"
partner1_name = "Bryan"
partner1_netid = "bmarty64"
partner1_favartist = "Kanye"

partner2_name = "Kasra"
partner2_netid = "kvak12"
partner2_favartist = "Lil Uzi"

partner3_name = ""
partner3_netid = ""
partner3_favartist= ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Exploring GPA

# %% [markdown]
# ## Load the GPA Dataset
#
# Before we begin exploring the GPA Dataset, we've got to load it in! The most recent version of the "GPA Dataset" (up to Spring 2022) is available here:
# ```
# https://waf.cs.illinois.edu/discovery/gpa.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
import pandas as pd
df = pd.read_csv('https://waf.cs.illinois.edu/discovery/gpa.csv')

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df) == 64048 ), "This is not the GPA dataset you're looking for"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.1: The "Average GPA" Column
# Each row in the GPA Dataset represents a **course** at Illinois. For our exploratory data analysis, we are going to need an additional `Average GPA` column.
#
# To create this column, we need to compute the **weighted average GPA** for each course by taking into account the **number of students** who received each letter grade.
#
# Add this new `Average GPA` column to our DataFrame `df` by finding the **products** of the **weight** associated with each **letter grade** by the amount of **students** in each course recieving said letter grade, **summing these products**, and then **dividing** by the **number of students** in the course.
#
# Remember:
# - The **weight** of letter grades are as follows: $[A+ = 4.0, A = 4.0, A- = 3.67, \ldots  D- = 0.67, F = 0]$. <br> You can find a full scale at: https://registrar.illinois.edu/courses-grades/explanation-of-grades/
# - The `Students` column of our DataFrame contains the number of students in a course
# - You've done this in your PrarieLearn homework before, now you're doing it for real :)

# %%
df['Average GPA'] = (4*df['A'] + 4*df['A+']+ 3.67*df['A-']+ 3.33*df['B+']+ 3.00*df['B']+ 2.67*df['B-']+ 2.33*df['C+']+ 2.0*df['C']+ 1.67*df['C-']+ 1.33*df['D+']+ 1*df['D']+ 0.67*df['D-']+ 0*df['F']) /df['Students']
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 1      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 2      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 3      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# 4      2022  Spring  2022-sp     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 64043  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 64044  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 64045  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 64046  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 64047  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C  C-  D+  D  D-  F  W  \
# 0            LCD   6  13   0  ...  3   0   1  1   0  0  0
# 1            DIS   0  11   5  ...  0   1   1  0   0  0  0
# 2            DIS   0  10   7  ...  0   0   0  0   0  2  0
# 3            DIS  17   8   1  ...  0   0   0  0   0  0  0
# 4             OD   0   8   4  ...  0   0   0  0   1  3  1
# ...          ...  ..  ..  ..  ... ..  ..  .. ..  .. .. ..
# 64043        LEC   5  10   2  ...  1   3   0  0   0  2  1
# 64044        LEC   4  12   8  ...  0   0   0  0   0  0  0
# 64045        LEC   0   1   3  ...  1   1   0  2   0  1  0
# 64046        LCD   1   2   2  ...  3   2   0  0   1  1  0
# 64047        LEC   5   8   9  ...  4   0   0  1   0  2  0
#
#              Primary Instructor  Students  Average GPA
# 0                   Lee, Sang S        29     3.413793
# 1                 Zheng, Reanne        25     3.440400
# 2                 Zheng, Reanne        27     3.358519
# 3      Rosado-Torres, Alexander        28     3.928571
# 4                      Wang, Yu        21     2.921429
# ...                         ...       ...          ...
# 64043        Stepanov, Alexei G        31     3.183226
# 64044              Unger, David        28     3.774643
# 64045         Morgan, William T        28     2.595714
# 64046  Ott-Monsivais, Stephanie        21     2.603333
# 64047          Keane, Richard D        39     3.205641
#
# [64048 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df) == 64048 ), "You shouldn't be changing the length of `df` when computing Average GPA"
assert( "Average GPA" in df.columns), "Make sure your new column is named 'Average GPA'"
assert( math.isclose(df['Average GPA'].mean(), 3.359779911362107)), "Your calculation of the Average GPA is incorrect."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.2: The "Hardest" and "Easiest" Courses?
# One way to judge a course's difficulty is to consider it's **Average GPA**.
#
# Using the `Average GPA` column and the two cells below, find:
# - The **50** courses with the **lowest** `Average GPA`, storing in the DataFrame `df_hard`
# - The **50** courses with the **highest** `Average GPA`, storing the DataFrame `df_easy`

# %%
df_hard = df.nsmallest(50,'Average GPA')
df_hard
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title  \
# 1227   2022  Spring  2022-sp      GS     199        College Academic Success
# 19204  2018    Fall  2018-fa     LER     120     Contemporary Labor Problems
# 3199   2021    Fall  2021-fa    CLCV     100  Vocab Building-GRK & LAT Roots
# 31676  2016  Spring  2016-sp     LER     100   Introduction to Labor Studies
# 39489  2014    Fall  2014-fa     LER     120     Contemporary Labor Problems
# 4301   2021    Fall  2021-fa     LER     100   Introduction to Labor Studies
# 41757  2014  Spring  2014-sp     LER     120     Contemporary Labor Problems
# 44554  2013    Fall  2013-fa    MATH       2            Introductory Algebra
# 41832  2014  Spring  2014-sp    MATH     220                        Calculus
# 16476  2019  Spring  2019-sp     LER     100   Introduction to Labor Studies
# 29404  2016    Fall  2016-fa     LER     120     Contemporary Labor Problems
# 29672  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 39536  2014    Fall  2014-fa     LLS     296   Bilingual US Latina/o Culture
# 39700  2014    Fall  2014-fa     MCB     245      Human Anat & Physiol Lab I
# 26605  2017  Spring  2017-sp     LER     100   Introduction to Labor Studies
# 20555  2018  Spring  2018-sp    CHEM     101          Introductory Chemistry
# 29400  2016    Fall  2016-fa     LER     100   Introduction to Labor Studies
# 2479   2022  Summer  2022-su    SPAN     141        Intro to Spanish Grammar
# 29403  2016    Fall  2016-fa     LER     110      Labor and Social Movements
# 55024  2011  Spring  2011-sp    MATH     115        Preparation for Calculus
# 29663  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 54960  2011  Spring  2011-sp     LER     100   Introduction to Labor Studies
# 41352  2014  Spring  2014-sp    ENGL     274           Contemporary Classics
# 34467  2015    Fall  2015-fa    MATH     181            A Mathematical World
# 19414  2018    Fall  2018-fa     MCB     245      Human Anat & Physiol Lab I
# 29668  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 7375   2021  Summer  2021-su    CHEM     102             General Chemistry I
# 53372  2011    Fall  2011-fa     TAM     251    Introductory Solid Mechanics
# 58580  2011  Summer  2011-su     TAM     251    Introductory Solid Mechanics
# 39285  2014    Fall  2014-fa      IE     300                Analysis of Data
# 46862  2013  Spring  2013-sp    MATH     115        Preparation for Calculus
# 17313  2019  Summer  2019-su    CHEM     102             General Chemistry I
# 52485  2011    Fall  2011-fa     LER     110      Labor and Social Movements
# 57693  2011  Summer  2011-su     LER     110      Labor and Social Movements
# 14455  2019    Fall  2019-fa     MCB     245      Human Anat & Physiol Lab I
# 26610  2017  Spring  2017-sp     LER     110      Labor and Social Movements
# 31680  2016  Spring  2016-sp     LER     110      Labor and Social Movements
# 29669  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 2478   2022  Summer  2022-su    SPAN     130            Intermediate Spanish
# 29402  2016    Fall  2016-fa     LER     110      Labor and Social Movements
# 39049  2014    Fall  2014-fa     FIN     300               Financial Markets
# 41734  2014  Spring  2014-sp     LER     100   Introduction to Labor Studies
# 6103   2021  Spring  2021-sp    ECON     302      Inter Microeconomic Theory
# 40430  2014  Spring  2014-sp     ACE     100      Agr Cons and Resource Econ
# 1533   2022  Spring  2022-sp     LER     100   Introduction to Labor Studies
# 4403   2021    Fall  2021-fa    MATH     124              Finite Mathematics
# 47077  2013  Spring  2013-sp     MCB     354    Biochem & Phys Basis of Life
# 943    2022  Spring  2022-sp    ECON     203          Economic Statistics II
# 37745  2015  Summer  2015-su    SPAN     103            Intermediate Spanish
# 33902  2015    Fall  2015-fa     FIN     300               Financial Markets
#
#       Sched Type  A+  A  A-  ...   C  C-  D+   D  D-   F  W  \
# 1227         LCD   1  0   0  ...   2   0   2   1   2  12  0
# 19204        ONL   0  0   1  ...   1   2   1   1   0  15  0
# 3199         ONL   2  0   3  ...   1   0   1   2   3  20  0
# 31676        ONL   0  1   0  ...   4   1   1   1   1  10  0
# 39489        ONL   0  4   0  ...   4   1   0   1   0  15  1
# 4301         ONL   0  1   0  ...   3   0   2   0   1  11  0
# 41757        ONL   0  1   3  ...   3   0   0   0   2  11  0
# 44554        LCD   0  0   0  ...  10   5   3   3   2   5  3
# 41832        LBD   0  3   0  ...   5   0   2   1   0  11  1
# 16476        ONL   0  2   1  ...   0   0   0   2   1   9  0
# 29404        NaN   0  2   2  ...   0   1   2   1   2   8  2
# 29672        NaN   0  0   0  ...   3   4   1   2   0   6  1
# 39536        LCD   3  1   0  ...   1   1   1   0   2  11  1
# 39700        LAB   0  0   1  ...   1   3   5   1   1   5  0
# 26605        NaN   0  2   1  ...   3   2   0   1   0   9  0
# 20555        NaN   1  5   8  ...  10   9  11  23  10  26  7
# 29400        NaN   0  2   1  ...   3   2   0   1   1  10  0
# 2479         ONL   0  1   0  ...   2   2   2   1   3   5  0
# 29403        NaN   0  4   2  ...   2   1   0   1   4   8  0
# 55024        LCD   1  4   2  ...   5   0   9  11   2  18  0
# 29663        NaN   0  0   1  ...   1   3   3   4   1   4  2
# 54960        ONL   2  1   0  ...   1   2   0   0   1   9  2
# 41352        LCD   0  1   3  ...   1   2   1   0   0   8  1
# 34467        LCD   1  3   0  ...   3   1   1   1   1   8  0
# 19414        LAB   0  0   1  ...   4   1   0   1   1   7  0
# 29668        NaN   0  0   1  ...   3   1   1   1   3   6  0
# 7375         ONL   2  3   4  ...  10   4   7  10  13  13  1
# 53372        LEC   1  0   4  ...  23   3   6  23   9  11  0
# 58580        LEC   1  0   4  ...  23   3   6  23   9  11  0
# 39285        LEC   4  1   3  ...  13  10   9   8   2  14  4
# 46862        LCD   0  3   5  ...   9   6   6   3   6  26  4
# 17313        ONL   0  2   2  ...   4   3   3   3   9  10  6
# 52485        ONL   0  3   0  ...   2   3   0   3   0   7  0
# 57693        ONL   0  3   0  ...   2   3   0   3   0   7  0
# 14455        LAB   0  0   1  ...   3   1   1   1   2   6  1
# 26610        NaN   0  3   2  ...   3   0   0   1   0  12  2
# 31680        ONL   0  1   4  ...   2   0   0   1   1   9  0
# 29669        NaN   1  0   0  ...   3   4   1   1   3   3  0
# 2478         ONL   0  1   0  ...   3   2   2   1   2   5  0
# 29402        NaN   0  2   2  ...   1   3   0   0   0  11  2
# 39049        LCD   0  0   1  ...   3   4   2   1   0   8  0
# 41734        ONL   0  1   1  ...   1   1   2   1   3   6  0
# 6103          OD   2  1   0  ...   3   2   0   2   1   8  0
# 40430        DIS   0  0   1  ...   2   2   1   1   5   2  0
# 1533         ONL   0  1   3  ...   3   1   0   2   0   7  0
# 4403         LCD   1  1   2  ...   2   3   0   0   1   8  0
# 47077        DIS   0  0   0  ...   3   3   1   3   1   2  0
# 943          LAB   2  1   0  ...   2   0   2   2   7   1  0
# 37745        LCD   0  0   0  ...   4   0   0   0   4   6  0
# 33902        LCD   0  1   0  ...   2   0   2   1   0   9  1
#
#               Primary Instructor  Students  Average GPA
# 1227               Walk, Aaron J        26     1.140385
# 19204                Taylor, Don        28     1.142857
# 3199       Augoustakis, Antonios        40     1.208750
# 31676           Hawking, Carol J        24     1.319583
# 39489          Hershfield, David        30     1.400000
# 4301               Ashby, Steven        26     1.410385
# 41757          Cohen, Margaret L        25     1.427600
# 44554        Aydin-Mullen, Yelda        31     1.430645
# 41832         Gilbert, Rebekah A        28     1.476071
# 16476          Cohen, Margaret L        21     1.491905
# 29404          Hershfield, David        22     1.515455
# 29672           Swigart, James P        23     1.522174
# 39536          Romero, Rolando J        27     1.568519
# 39700           Swigart, James P        25     1.586800
# 26605              Ashby, Steven        23     1.594783
# 20555          Decoste, Donald J       132     1.598864
# 29400         Stewart, Beverly L        27     1.605185
# 2479        Castro Cantu, Sara E        22     1.606364
# 29403              Ashby, Steven        25     1.614400
# 55024            Carty, Thomas E        71     1.619296
# 29663           Swigart, James P        25     1.626800
# 54960            Konopacki, Mike        22     1.636364
# 41352             Hutner, Gordon        21     1.651429
# 34467              Loeb, Sarah J        23     1.651739
# 19414           Swigart, James P        23     1.652174
# 29668           Swigart, James P        26     1.654231
# 7375             Marville, Kelly        85     1.655294
# 53372       Starzewski, Martin O       102     1.657157
# 58580       Starzewski, Martin O       102     1.657157
# 39285             Tursun, Umit D        75     1.662400
# 46862        Lansing, Jennifer L        96     1.663438
# 17313            Marville, Kelly        52     1.667115
# 52485              Saute, Robert        24     1.680417
# 57693              Saute, Robert        24     1.680417
# 14455           Swigart, James P        24     1.681250
# 26610         Schiavone, Michael        29     1.701724
# 31680              Ashby, Steven        25     1.707200
# 29669           Swigart, James P        24     1.708750
# 2478           Strocchia, Ilaria        23     1.710435
# 29402         Schiavone, Michael        29     1.713103
# 39049             Waspi, Kevin G        32     1.719063
# 41734        Hertenstein, Edward        25     1.733600
# 6103                Kim, Sarah J        28     1.749643
# 40430          Gundersen, Lisa C        23     1.754348
# 1533               Ashby, Steven        22     1.758182
# 4403                Dao, Quang N        25     1.760800
# 47077       Stenger, Alejandra L        21     1.777619
# 943    Martinez Garcia, Humberto        21     1.778571
# 37745             Lugo, Monica E        28     1.785714
# 33902             Waspi, Kevin G        30     1.788667
#
# [50 rows x 24 columns]

# %%
df_easy = df.nlargest(50,'Average GPA')
df_easy
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title  \
# 17380  2019  Summer  2019-su      IS     532    Theory & Pract Data Cleaning
# 7445   2021  Summer  2021-su      IS     537  Theory & Prct of Data Cleaning
# 30334  2016  Spring  2016-sp    ACCY     398       Practical Problems in Atg
# 26247  2017  Spring  2017-sp    EPSY     490  Prep for Recruitment Counselor
# 39769  2014    Fall  2014-fa      ME     199      Automotive Design Projects
# 27837  2016    Fall  2016-fa    ANSC     103       Working With Farm Animals
# 32808  2015    Fall  2015-fa    ANSC     103       Working With Farm Animals
# 2291   2022  Spring  2022-sp     VCM     673          Companion Animal Rehab
# 49838  2012    Fall  2012-fa     MUS     273                 Marching Illini
# 44156  2013    Fall  2013-fa      GS     101       Exploring General Studies
# 1395   2022  Spring  2022-sp      IS     534          Information Consulting
# 13754  2019    Fall  2019-fa     FIN     447         Real Estate Development
# 25484  2017  Spring  2017-sp    BADM     566         Supply Chain Management
# 24040  2017    Fall  2017-fa      IB     199      Undergraduate Open Seminar
# 3691   2021    Fall  2021-fa    EPOL     500              Proseminar in EPOL
# 8621   2020    Fall  2020-fa    EPSY     408    Learning & Hum Dev w/ EdTech
# 21167  2018  Spring  2018-sp    EPSY     490  Prep for Recruitment Counselor
# 25185  2017  Spring  2017-sp    ACCY     398       Practical Problems in Atg
# 4648   2021    Fall  2021-fa    MUSC     480                   Wind Symphony
# 40223  2014    Fall  2014-fa    SPED     405     Gen Educator's Role in SPED
# 4483   2021    Fall  2021-fa     MBA     564   Applying Data Analytics Mrktg
# 5968   2021  Spring  2021-sp    DANC     100     Intro to Contemporary Dance
# 7983   2020    Fall  2020-fa    BADM     567              Process Management
# 10130  2020  Spring  2020-sp    ANSC     103       Working With Farm Animals
# 15664  2019  Spring  2019-sp      CI     473           Disciplinary Literacy
# 7287   2021  Spring  2021-sp      TE     360  Lect in Engrg Entrepreneurship
# 45889  2013  Spring  2013-sp    CHLH     380       Orientation to Internship
# 6215   2021  Spring  2021-sp     EPS     533    Global Youth and Citizenship
# 26932  2017  Spring  2017-sp     MUS     274                 Basketball Band
# 12086  2020  Summer  2020-su    EPSY     408    Learning & Hum Dev w/ EdTech
# 12311  2020  Winter  2020-wi    EPSY     408    Learning & Hum Dev w/ EdTech
# 18603  2018    Fall  2018-fa    EDUC     101   Education Orientation Seminar
# 26928  2017  Spring  2017-sp     MUS     250                  Illini Strings
# 34748  2015    Fall  2015-fa     MUS     262               Women's Glee Club
# 473    2022  Spring  2022-sp     BUS     301              Business in Action
# 55278  2011  Spring  2011-sp     MSE     183   Freshman Materials Laboratory
# 6511   2021  Spring  2021-sp      IS     507                Data, Stat, Info
# 27992  2016    Fall  2016-fa    BADM     420   Advanced Marketing Management
# 345    2022  Spring  2022-sp    BADM     324     Purchasing and Supply Mgmnt
# 38141  2014    Fall  2014-fa    BADM     261       Technology & Mgmt Seminar
# 45914  2013  Spring  2013-sp      CI     473       Literacy in Content Areas
# 8627   2020    Fall  2020-fa    EPSY     559  Advanced Learning Technologies
# 14744  2019    Fall  2019-fa    PSYC     506           Statistical Methods I
# 17608  2018    Fall  2018-fa    ACCY     518       Financial Statement Fraud
# 31047  2016  Spring  2016-sp    EALC     365     Contemporary Korean Society
# 39837  2014    Fall  2014-fa     MUS     250                  Illini Strings
# 48138  2012    Fall  2012-fa    BADM     261       Technology & Mgmt Seminar
# 36994  2015  Spring  2015-sp     MUS     262               Women's Glee Club
# 22974  2017    Fall  2017-fa    BIOE     303     Quantitative Physiology Lab
# 28991  2016    Fall  2016-fa    FSHN     519   Flavor Chemistry and Analysis
#
#       Sched Type   A+    A  A-  ...  C  C-  D+  D  D-  F  W  \
# 17380        ONL  266   18   1  ...  0   0   0  0   0  0  0
# 7445         ONL  407    9   0  ...  0   0   0  0   0  0  0
# 30334        ONL  139    1   0  ...  0   0   0  0   0  0  0
# 26247        NaN   69   14   0  ...  0   0   0  0   0  0  0
# 39769        LBD    8  111   0  ...  0   0   0  0   0  0  0
# 27837        NaN    0   79   0  ...  0   0   0  0   0  0  0
# 32808        LEC    0   76   0  ...  0   0   0  0   0  0  0
# 2291         LCD   69    2   0  ...  0   0   0  0   0  0  0
# 49838         PR    0  308   0  ...  0   0   0  0   0  0  0
# 44156        LCD    0   66   0  ...  0   0   0  0   0  0  0
# 1395         LCD    0   65   0  ...  0   0   0  0   0  0  0
# 13754        LCD   11   53   0  ...  0   0   0  0   0  0  0
# 25484        NaN   32   25   0  ...  0   0   0  0   0  0  0
# 24040        NaN    0   81   0  ...  0   0   0  0   0  0  1
# 3691         ONL    0   80   0  ...  0   0   0  0   0  0  0
# 8621         ONL   69   10   1  ...  0   0   0  0   0  0  0
# 21167        NaN   43   37   0  ...  0   0   0  0   0  0  0
# 25185        NaN  123    6   1  ...  0   0   0  0   0  0  0
# 4648          PR    0   51   0  ...  0   0   0  0   0  0  0
# 40223        LCD   40   10   0  ...  0   0   0  0   0  0  0
# 4483         ONL    0  680   0  ...  0   0   0  0   0  2  1
# 5968         ONL   39   10   0  ...  0   0   0  0   0  0  0
# 7983         ONL   45    4   0  ...  0   0   0  0   0  0  0
# 10130        LEC    0   73   0  ...  0   0   0  0   0  0  0
# 15664        LEC    0   94   2  ...  0   0   0  0   0  0  0
# 7287         OLC   47    0   0  ...  0   0   0  0   0  0  0
# 45889        LCD    0  117   0  ...  0   0   0  0   0  0  0
# 6215         ONL    4   42   0  ...  0   0   0  0   0  0  0
# 26932        NaN    0  138   0  ...  1   0   0  0   0  0  0
# 12086        ONL   79   31   3  ...  0   0   0  0   0  0  2
# 12311        ONL   79   31   3  ...  0   0   0  0   0  0  2
# 18603        LCD    0   67   0  ...  0   0   0  0   0  0  1
# 26928        NaN    0   67   0  ...  0   0   0  0   0  0  0
# 34748         PR   11   56   0  ...  0   0   0  0   0  0  0
# 473          LCD    0   44   0  ...  0   0   0  0   0  0  0
# 55278        LBD    0   66   0  ...  0   0   0  0   0  0  0
# 6511         ONL   38    5   0  ...  0   0   0  0   0  0  0
# 27992        NaN    0   64   0  ...  0   0   0  0   0  0  0
# 345          LCD   49   13   1  ...  0   0   0  0   0  0  0
# 38141        LCD    0   62   0  ...  0   0   0  0   0  0  0
# 45914        LEC   37   23   1  ...  0   0   0  0   0  0  0
# 8627         ONL   30   10   0  ...  0   0   0  0   0  0  0
# 14744        LEC   16   24   0  ...  0   0   0  0   0  0  0
# 17608        LCD   32    8   0  ...  0   0   0  0   0  0  0
# 31047        LCD    0   40   0  ...  0   0   0  0   0  0  0
# 39837         PR    0   60   0  ...  0   0   0  0   0  0  0
# 48138        LCD    0   60   0  ...  0   0   0  0   0  0  0
# 36994         PR    0   59   0  ...  0   0   0  0   0  0  0
# 22974        NaN    0   39   0  ...  0   0   0  0   0  0  0
# 28991        NaN    8   31   0  ...  0   0   0  0   0  0  0
#
#              Primary Instructor  Students  Average GPA
# 17380       Ludaescher, Bertram       286     3.995350
# 7445                        NaN       419     3.995203
# 30334            Nekrasz, Frank       141     3.992908
# 26247             Brown, Dawn M        84     3.992024
# 39769       Philpott, Michael L       120     3.991667
# 27837              Cobb, Alan R        80     3.991625
# 32808              Cobb, Alan R        77     3.991299
# 2291           Knap, Kimberly E        72     3.990694
# 49838           Houser, Barry L       311     3.990354
# 44156  Armstrong, Christopher M        67     3.990000
# 1395            Song, Yoo-Seong        66     3.989848
# 13754         Cannaday, Roger E        65     3.989692
# 25484        Mukherjee, Ujjal K        58     3.988448
# 24040      Arias Chauca, Lily C        82     3.987805
# 3691              Lee, Sharon S        81     3.987654
# 8621              Cope, William        81     3.987654
# 21167             Brown, Dawn M        81     3.987654
# 25185            Nekrasz, Frank       132     3.987348
# 4648          Peterson, Stephen        52     3.987115
# 40223         Taylor, Gregory G        51     3.986863
# 4483              Yun, Joseph T       683     3.986823
# 5968          Sapozhnikov, Anna        50     3.986600
# 7983           Cockrell, Adam L        50     3.986600
# 10130           Emmert, Jason L        74     3.986486
# 15664          Filkins, Scott R        97     3.986289
# 7287    Harbourt, Christopher M        48     3.986042
# 45889           Farner, Susan M       119     3.985966
# 6215             Herrera, Linda        47     3.985745
# 26932           Houser, Barry L       139     3.985612
# 12086             Cope, William       114     3.985439
# 12311             Cope, William       114     3.985439
# 18603           Jo, Katherine K        68     3.985294
# 26928            May, Cameron L        68     3.985294
# 34748             Solya, Andrea        68     3.985294
# 473                 Kim, Heejin        45     3.985111
# 55278             Braun, Paul V        67     3.985075
# 6511        Besser, Stephanie A        44     3.984773
# 27992           Wolters, Mark E        65     3.984615
# 345            Cockrell, Adam L        64     3.984375
# 38141           Quarton, John E        63     3.984127
# 45914          Dressman, Mark A        62     3.983871
# 8627            Kalantzis, Mary        41     3.983659
# 14744         Gratton, Gabriele        41     3.983659
# 17608            Nekrasz, Frank        41     3.983659
# 31047           Cagle, Robert L        41     3.983659
# 39837            Giem, Nathan G        61     3.983607
# 48138          Sementi, Darcy A        61     3.983607
# 36994             Solya, Andrea        60     3.983333
# 22974        Marjanovic, Marina        40     3.983250
# 28991      Cadwallader, Keith R        40     3.983250
#
# [50 rows x 24 columns]

# %% [markdown]
# Now, using your two new DataFrames (`df_hard` and `df_easy`), find:
# - The **mean course number** of the 50 hardest courses by GPA, storing in the variable `hard_avg`
# - The **mean course number** of the 50 easiest courses by GPA, storing in the variable `easy_avg`
#
# The **course number** of a course is stored in the **'Number'** column of our DataFrames.

# %%
hard_avg = df_hard['Number'].mean()
hard_avg
# Out:
# 166.42

# %%
easy_avg = df_easy['Number'].mean()
easy_avg
# Out:
# 372.62

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell(s), make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_hard) == len(df_easy) == 50 ), "Your df_hard and df_easy should be picking the 50 courses with the lowest / highest average GPA respectively. Please double check that you are selecting 50 courses."
assert( math.isclose(df_hard['Average GPA'].sum(), 80.30481775738464) ), "Your df_hard is calculated incorrectly. Make sure you are finding the 50 courses with the lowest Average GPA."
assert( math.isclose(df_easy['Average GPA'].sum(), 199.34775533302954) ), "Your df_easy is calculated incorrectly. Make sure you are finding the 50 courses with the highest Average GPA."
assert( math.isclose(hard_avg, 166.42) ), "Your calculation for the average course Number of 'hard' courses is incorrect. Make sure you are finding the mean of course numbers of df_hard."
assert( math.isclose(easy_avg, 372.62) ), "Your calculation for the average course Number of 'easy' courses is incorrect. Make sure you are finding the mean of coure numbers of df_easy."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: "Hardest" and "Easiest" Courses?
#
# **Q1: After solving Puzzle 1.2, your friend has the following claim:**
#
# > *"We know that the undergraduate courses are coded from 001 to 499, where a larger number (in the hundreds place) usually implies more advanced material.  Based on our results in the previous puzzles, the data shows that the junior-level and senior-level courses are clearly not the hardest courses at UIUC."*
#
# **Comment on your friend's claim below. Do you think they are correct? Explain why or why not in at least three complete sentences.**

# %% [markdown]
# No, they are not correct because there can be confounders and other variables skewing our average GPA calculations. Also we are only taking an average of the course numbers so it is an approximation and not completely representative of all subjects and course numbers. It would be more accurate if we looked at other measurements such as median, standard deviation, and variance and used those to aid in our comparison.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: GPA By Subject
# We've explored some of the GPA Dataset as a whole, but what if we want to investigate **differences in GPA by subject**?

# %% [markdown]
# ### Puzzle 2.1: Grouping by Subject
# To look into the different Average GPAs for each Subject, we need to **group** our DataFrame.
#
# In the following cell, create a new DataFrame, `df_subject`, which will contain this grouped GPA data. Using `df.groupby()`, **group** our original DataFrame (`df`) by `Subject` so each **letter grade column** contains the **total number of students** recieving said grade in that `Subject`.
#
# Remember: each row **before grouping** represents a **course** inside of a `Subject` with the **number of students** recieving grades for that course. This might help you decide what type of **aggregation** (`.agg()`) to use when **grouping**. And, don't forget to `.reset_index()`!

# %%
df_subject = df.groupby('Subject').agg('sum').reset_index()
df_subject
# Out:
# C:\Users\nrefa\AppData\Local\Temp\ipykernel_3248\3599147446.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_subject = df.groupby('Subject').agg('sum').reset_index()
#     Subject     Year  Number     A+      A     A-     B+      B    B-    C+  \
# 0       AAS   457622   28869   1001   2632    985    624    633   287   166
# 1       ABE   312439   52017    476   2940    871    796    992   263   147
# 2      ACCY  5338022  991212  11205  31561  19913  18215  17110  7121  3563
# 3       ACE  2114595  293541   5964  17395   6134   5115   8440  3090  1987
# 4      ACES   342649   19757   1240   2016    318    160    312    81    83
# ..      ...      ...     ...    ...    ...    ...    ...    ...   ...   ...
# 165      UP   675240  119903   1334   4338   2328   1392   1483   552   289
# 166      VB     8040    2489      0    212      6      6    120     1     0
# 167     VCM    80511   26067    380   1376     29     50   1040    20    19
# 168      VM   229843   69469      0   2386      8      0   7082     1     0
# 169    YDSH    28196    3880     56    114     87     37     44    16    10
#
#         C    C-   D+    D   D-    F    W  Students  Average GPA
# 0     173    68   38   42   22  112   25      6783   795.588141
# 1     193    50   17   49    8   68   17      6870   541.883527
# 2    2836  1397  404  805  249  756  316    115135  8993.159074
# 3    2874   948  451  823  265  907  128     54393  3460.535150
# 4      98    36   23   31   16   89    9      4503   623.023691
# ..    ...   ...  ...  ...  ...  ...  ...       ...          ...
# 165   324   149   47   96   61  213   42     12606  1171.416786
# 166    40     0    0    2    0    0    0       387    13.974534
# 167   337     1    1   41    0    2    0      3296   139.754516
# 168  4204     0    0  448    0   15   10     14144   322.761836
# 169     7     5    1    2    2   10    3       391    48.795454
#
# [170 rows x 19 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell(s), make changes, and RE-RUN your code and then this cell.
import math
assert( 'df_subject' in vars() ), "Make sure your DataFrame grouped by Subject is named 'df_subject'." 
assert( len(df_subject) == 170 ), "Make sure you are grouping by 'Subject'. There are 170 Subjects in our original `df`, so the length of `df_subject` should be 170."
assert( math.isclose(df_subject.Students.mean(), 22003.170588235294) ), "Double-check that you are aggregating your df_subject correctly. "

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Fixing our `Average GPA` Column
# Your intuition may tell you that some columns in `df_subject` look off. This is correct - given the way we've grouped the data to find **total student counts** by grade , the `Year` and `Average GPA` columns are incorrect.
#
# Let's fix this by redefining the `Average GPA` column in our `df_subject`.
#
# The `Average GPA` column should contain the **weighted average GPA** of each `Subject` by taking into account the **number of students** who received each letter grade in said `Subject`.
#
# Remember:
# - The **weight** of letter grades are as follows: $[A+ = 4.0, A = 4.0, A- = 3.67, \ldots  D- = 0.67, F = 0]$. <br> You can find a full scale at: https://registrar.illinois.edu/courses-grades/explanation-of-grades/
# - The `Students` column of our DataFrame contains the number of students in a `Subject`
# - This Puzzle is **strikingly similar** to **Puzzle 1.1** in this lab - just make sure you use `df_subject` this time!

# %%
df_subject['Average GPA'] = (4*df_subject['A'] + 4*df_subject['A+']+ 3.67*df_subject['A-']+ 3.33*df_subject['B+']+ 3.00*df_subject['B']+ 2.67*df_subject['B-']+ 2.33*df_subject['C+']+ 2.0*df_subject['C']+ 1.67*df_subject['C-']+ 1.33*df_subject['D+']+ 1*df_subject['D']+ 0.67*df_subject['D-']+ 0*df_subject['F']) /df_subject['Students']
df_subject
# Out:
#     Subject     Year  Number     A+      A     A-     B+      B    B-    C+  \
# 0       AAS   457622   28869   1001   2632    985    624    633   287   166
# 1       ABE   312439   52017    476   2940    871    796    992   263   147
# 2      ACCY  5338022  991212  11205  31561  19913  18215  17110  7121  3563
# 3       ACE  2114595  293541   5964  17395   6134   5115   8440  3090  1987
# 4      ACES   342649   19757   1240   2016    318    160    312    81    83
# ..      ...      ...     ...    ...    ...    ...    ...    ...   ...   ...
# 165      UP   675240  119903   1334   4338   2328   1392   1483   552   289
# 166      VB     8040    2489      0    212      6      6    120     1     0
# 167     VCM    80511   26067    380   1376     29     50   1040    20    19
# 168      VM   229843   69469      0   2386      8      0   7082     1     0
# 169    YDSH    28196    3880     56    114     87     37     44    16    10
#
#         C    C-   D+    D   D-    F    W  Students  Average GPA
# 0     173    68   38   42   22  112   25      6783     3.515226
# 1     193    50   17   49    8   68   17      6870     3.504868
# 2    2836  1397  404  805  249  756  316    115135     3.413034
# 3    2874   948  451  823  265  907  128     54393     3.311314
# 4      98    36   23   31   16   89    9      4503     3.641561
# ..    ...   ...  ...  ...  ...  ...  ...       ...          ...
# 165   324   149   47   96   61  213   42     12606     3.455461
# 166    40     0    0    2    0    0    0       387     3.448760
# 167   337     1    1   41    0    2    0      3296     3.407949
# 168  4204     0    0  448    0   15   10     14144     2.805291
# 169     7     5    1    2    2   10    3       391     3.446394
#
# [170 rows x 19 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_subject) == 170 ), "You shouldn't be changing the length of `df_subject` when recomputing Average GPA"
assert( "Average GPA" in df_subject.columns), "Make sure your column is still named 'Average GPA'."
assert( len(df_subject.columns) == 19), "Don't add any new columns to df_subject when recalculating the 'Average GPA' column."
assert( math.isclose(df_subject['Average GPA'].mean(), 3.4581205344558357) ), "Your calculation of the Average GPA by Subject is incorrect."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.3: The "Hardest" and "Easiest" Subjects?
# One way we can judge a Subject's difficulty is to consider it's **Average GPA**.
#
# Using your `df_subject`'s  `Average GPA` column and the two cells below, find:
# - The **10** Subjects with the **lowest** `Average GPA`, storing in the DataFrame `hard_subjects`
# - The **10** Subjects with the **highest** `Average GPA`, storing the DataFrame `easy_subjects`

# %%
hard_subjects = df_subject.nsmallest(10,'Average GPA')
hard_subjects
# Out:
#     Subject     Year  Number     A+      A     A-     B+      B     B-     C+  \
# 168      VM   229843   69469      0   2386      8      0   7082      1      0
# 159     TAM   707446  110319   2409   5589   4234   4072   4882   3239   2540
# 113    MATH  5141035  791766  14715  36725  22590  22356  29269  17479  14777
# 130    PHYS  1947188  279758  16904  18797  12873  12074  12617  11205   9155
# 106     LAT    12076     613     14     20     17     16     21      7     14
# 145    SAME     6039     437      2     29     30     20     31     12     14
# 40     CHBE   625040  129743    882   4291   2248   2223   3872   1822   1411
# 41     CHEM  3770620  362458  16396  52401  21671  20993  27469  15965  14440
# 115     MCB  4430296  560516   8958  16564  13335  12630  14389   8715   6439
# 129    PHIL  1144312   96229    926   4403   3546   2952   2860   1765    958
#
#          C    C-    D+     D    D-     F     W  Students  Average GPA
# 168   4204     0     0   448     0    15    10     14144     2.805291
# 159   2652  1594   961  1173   545  1331   175     35221     2.870024
# 113  17452  9130  5131  6429  2666  8317  1643    207036     2.884560
# 130   8983  6759  4243  3083  3580  1987   785    122260     2.942354
# 106      6     3     1     3     2     8     0       132     2.944394
# 145     17     5     2     2     3     5     1       172     2.949884
# 40    2393   812   174   388    73   294    78     20883     3.013144
# 41   16950  9337  4591  4827  2609  4849  1329    212498     3.037581
# 115   5956  3427  1974  1583   899  1403   426     96272     3.084699
# 129    831   457   200   278   200   868   122     20244     3.101554

# %%
easy_subjects = df_subject.nlargest(10,'Average GPA')
easy_subjects
# Out:
#     Subject    Year  Number    A+     A    A-   B+    B   B-  C+   C  C-  D+  \
# 68     ERAM    4044    1113    17    47     5    0    1    0   0   0   0   0
# 122    MUSC   32343    7527    98   639    22   14   15    1   1   2   1   0
# 38       CB    4022    1250     0   140     0    0   17    0   0   1   0   0
# 13     ALEC    8083    1211    60    60     7    3    3    1   1   0   0   2
# 164     UKR    8048     452     5   190    43   20    8    4   0   1   0   0
# 65     EPOL  123286   30075   318  1712   261   96   50   28   7   7   5   1
# 37      BUS  739944   48226  1094  7615  1367  604  355  112  50  51  13  14
# 137    REES    6047     603    32    34     7    2    5    2   0   0   0   0
# 44      CHP   32306    3381   144   213    45   13   15    4   2   5   1   1
# 64      EOL  120952   32561    94  1376   267  130  104   12   4   9   0   0
#
#       D  D-   F   W  Students  Average GPA
# 68    1   0   0   0        71     3.920423
# 122   1   0  10   1       804     3.895560
# 38    0   0   0   2       158     3.879747
# 13    0   0   1   0       138     3.857536
# 164   0   0   0   0       271     3.841661
# 65    4   0  29   5      2518     3.838880
# 37   16   8  39  13     11338     3.837400
# 137   1   0   0   0        83     3.827590
# 44    0   0   4   0       447     3.825011
# 64    6   0  10   3      2012     3.812202

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(hard_subjects) == len(easy_subjects) == 10 ), "Make sure you are selecting the ten hardest or easiest subjects by GPA. This means your hard_subjects and easy_subjects DataFrames should both have exactly ten rows."
assert( math.isclose(hard_subjects['Average GPA'].sum(), 29.63348355865901) ), "Your calculation for the hardest subjects by GPA is incorrect. Remember, here harder = lower Average GPA."
assert( math.isclose(easy_subjects['Average GPA'].sum(), 38.536009114732316) ), "Your calculation for the easiest subjects by GPA is incorrect. Remember, here easier = higher Average GPA."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: "Hardest" and "Easiest" Subjects?
#
# **Q2: Observe the `Subject` column of the `hard_subjects` and `easy_subjects` you've found in Puzzle 2.3 above. Do you think these are truly the "Hardest" and "Easiest" subjects at Illinois? Explain why or why not.**
#
#
# *Note: You can use http://catalog.illinois.edu/courses-of-instruction/ to find what the different `Subject` codes mean.*

# %% [markdown]
# Yes, I believe that this is a better visualization of harder and easier subjects. The subjects in hard_subjects include subjects like math, physics, and engineering which makes sense why they have a lower average GPA. On the other hand, easy subjects like Music and other humanities are placed in easy_subjects will also makes sense intuitively because those types of Subject require a lot less cognitive work to perform well, making them easier to obtain a higher GPA in.

# %% [markdown]
# ### Puzzle 2.4: Visualizing GPA by Subject
# We've got the **Average GPA** of each `Subject` at Illinois, but what if we want to look at the **bigger picture** across all Subjects? Well, Data Visualization comes to the rescue!
#
# Using your knowledge of `.hist()`, generate a **histogram** of the **Average GPA** in your `df_subject`:

# %%
df_subject['Average GPA'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Analysis: Histogram Interpretations
#
# **Q3: Based on the histogram you generated above, what do you think the Average GPA across all courses in a typical Subject at Illinois is? No need for an exact answer, just estimate.**

# %% [markdown]
# Based on this histogram, I can visually determine that the average GPA across all courses is around 3.5

# %% [markdown]
# ### Puzzle 2.5: Your Major!
# We've done a lot of analysis on every course and every subject, but Data Science should also be personal to you!
#
# Using your `df_subject`, isolate the row containing the `Subject` of **your Major**, storing in the variable `my_subject`:
#
# (If you're undecided, you can pick any `Subject`!)

# %%
my_subject = df_subject.loc[df_subject.Subject == 'BIOE']
my_subject
# Out:
#    Subject    Year  Number    A+     A    A-    B+     B   B-   C+    C   C-  \
# 34    BIOE  554510   94023  2156  4888  2041  1315  1413  470  281  289  110
#
#     D+   D  D-   F   W  Students  Average GPA
# 34  49  63  27  69  13     13171     3.576191

# %% [markdown]
# ### Analysis: Your Major's Average GPA
#
# **Q4: Observe the `Average GPA` column of your subject from Puzzle 2.5 above. Is it higher or lower than you expected?**

# %% [markdown]
# The average GPA is 3.57 - This is not higher than I expected because it's pretty reasonably close to 3.5

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: GPA By Year
# At this point, we've investigated the GPA Dataset as a whole and grouped by `Subject`. While our GPA Dataset contains **a lot** of course data, some of the listed courses are quite old: **dating back to 2010**! To put that into perspective, a senior in college now would be no more than **10 years old** in 2010.
#
# One can question the changes to GPA **over time**. Some questions may include:
# - Has GPA gone down, because classes became "easier"?
# - Has the GPA risen because of stricter grading policies?
# - How was GPA impacted in 2019-2020 at the brunt of COVID?
#
# You will gain some insight into the answers to questions in this section of the lab.

# %% [markdown]
# ### Puzzle 3.1: Grouping by Year
# To look into how the GPA changes by `Year`, we need to again **group** our DataFrame.
#
# In the following cell, create a new DataFrame, `df_year`, which will contain this grouped GPA data. Using `df.groupby()`, **group** our original DataFrame (`df`) by `Year` so each **letter grade column** contains the **total number of students** recieving said grade in that `Year`.
#
# Remember: You did something quite similar in Puzzle 2.1 to create `df_subject`. This might help you decide what type of **aggregation** (`.agg()`) to use when **grouping**. And, don't forget to `.reset_index()`!

# %%
df_year = df.groupby('Year').agg('sum').reset_index()
df_year
# Out:
# C:\Users\nrefa\AppData\Local\Temp\ipykernel_3248\4268912385.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_year = df.groupby('Year').agg('sum').reset_index()
#     Year   Number     A+       A     A-     B+      B     B-     C+      C  \
# 0   2010  1493480  19355   77012  36814  30579  43517  17195  11604  15753
# 1   2011  2180531  30104  116873  56123  47410  64714  25734  17362  23971
# 2   2012   822949  11834   44738  20603  17041  22408   9485   6515   8221
# 3   2013  1468576  22541   81114  37513  30624  40241  17471  11611  14875
# 4   2014  1442419  25404   79518  36863  30783  38716  17733  11728  14813
# 5   2015  1518025  29005   87375  39421  31956  40279  18204  12288  14909
# 6   2016  1453915  29090   85566  37979  30316  37737  16756  11627  14213
# 7   2017  1513870  34894   92185  38313  29892  37507  16522  11096  14282
# 8   2018  1509394  40121   98620  39606  29496  35840  16097  10811  13404
# 9   2019  1528969  41642  104139  40875  30890  37332  16680  11203  13623
# 10  2020  1471255  60274  122425  40348  26705  30961  13123   8766  10349
# 11  2021  1552963  64135  119896  40970  28039  31907  13956   9653  11625
# 12  2022   794300  29890   62378  20785  14941  17082   7246   4827   5956
#
#       C-    D+     D    D-     F     W  Students   Average GPA
# 0   5812  2975  4438  1506  4511  1404    271071  17983.181282
# 1   9576  4429  6884  2517  7389  1833    413086  26391.118984
# 2   3307  1690  2218   936  2681   626    151677   9532.509354
# 3   6367  3103  4263  1851  4895  1072    276469  16764.437980
# 4   6584  3258  4644  2073  5380  1293    277497  16395.289276
# 5   6583  3562  4537  2057  5572  1327    295748  17399.314543
# 6   6120  3325  4273  1964  5800  1254    284766  16612.060181
# 7   6128  3252  4600  2013  6161  1295    296845  17131.289555
# 8   5949  3335  4353  2042  6251  1121    305925  17000.203298
# 9   6117  3283  4434  2212  6914  1146    319344  16983.843455
# 10  4916  1927  2718  1228  6106   349    329846  16936.637063
# 11  5458  3196  3941  2010  9004  1219    343790  17513.454652
# 12  2749  1435  1940   963  4283   830    174475   8543.844140

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( 'df_year' in vars() ), "Make sure your DataFrame grouped by Year is named 'df_year'." 
assert( len(df_year) == 13 ), "Make sure you are grouping by 'Year'. There are 13 years in our original `df`, so the length of `df_years` should be 13."
assert( math.isclose(df_year.Students.mean(), 287733.76923076925) ), "Double-check that you are aggregating your df_year correctly. "

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.2: Fixing our `Average GPA` Column Again
# Some columns in `df_year` are incorrectly calculated given the way we've grouped the data.
#
# Let's fix this by redefining the `Average GPA` column in our `df_year`.
#
# The `Average GPA` column should contain the **weighted average GPA** of each `Year` by taking into account the **number of students** who received each letter grade in said `Year`.
#
# Remember: You've done this twice before in **Puzzle 1.1** and **Puzzle 2.1** - just make sure you use `df_year` this time!

# %%
df_year['Average GPA'] = (4*df_year['A'] + 4*df_year['A+']+ 3.67*df_year['A-']+ 3.33*df_year['B+']+ 3.00*df_year['B']+ 2.67*df_year['B-']+ 2.33*df_year['C+']+ 2.0*df_year['C']+ 1.67*df_year['C-']+ 1.33*df_year['D+']+ 1*df_year['D']+ 0.67*df_year['D-']+ 0*df_year['F']) /df_year['Students']
df_year
# Out:
#     Year   Number     A+       A     A-     B+      B     B-     C+      C  \
# 0   2010  1493480  19355   77012  36814  30579  43517  17195  11604  15753
# 1   2011  2180531  30104  116873  56123  47410  64714  25734  17362  23971
# 2   2012   822949  11834   44738  20603  17041  22408   9485   6515   8221
# 3   2013  1468576  22541   81114  37513  30624  40241  17471  11611  14875
# 4   2014  1442419  25404   79518  36863  30783  38716  17733  11728  14813
# 5   2015  1518025  29005   87375  39421  31956  40279  18204  12288  14909
# 6   2016  1453915  29090   85566  37979  30316  37737  16756  11627  14213
# 7   2017  1513870  34894   92185  38313  29892  37507  16522  11096  14282
# 8   2018  1509394  40121   98620  39606  29496  35840  16097  10811  13404
# 9   2019  1528969  41642  104139  40875  30890  37332  16680  11203  13623
# 10  2020  1471255  60274  122425  40348  26705  30961  13123   8766  10349
# 11  2021  1552963  64135  119896  40970  28039  31907  13956   9653  11625
# 12  2022   794300  29890   62378  20785  14941  17082   7246   4827   5956
#
#       C-    D+     D    D-     F     W  Students  Average GPA
# 0   5812  2975  4438  1506  4511  1404    271071     3.233537
# 1   9576  4429  6884  2517  7389  1833    413086     3.228032
# 2   3307  1690  2218   936  2681   626    151677     3.253189
# 3   6367  3103  4263  1851  4895  1072    276469     3.250664
# 4   6584  3258  4644  2073  5380  1293    277497     3.240724
# 5   6583  3562  4537  2057  5572  1327    295748     3.266786
# 6   6120  3325  4273  1964  5800  1254    284766     3.275170
# 7   6128  3252  4600  2013  6161  1295    296845     3.301471
# 8   5949  3335  4353  2042  6251  1121    305925     3.337837
# 9   6117  3283  4434  2212  6914  1146    319344     3.339275
# 10  4916  1927  2718  1228  6106   349    329846     3.489987
# 11  5458  3196  3941  2010  9004  1219    343790     3.424277
# 12  2749  1435  1940   963  4283   830    174475     3.427097

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 3.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_year) == 13 ), "You shouldn't be changing the length of `df_year` when recomputing Average GPA"
assert( "Average GPA" in df_year.columns), "Make sure your column is still named 'Average GPA'."
assert( len(df_year.columns) == 18), "Don't add any new columns to df_year when recalculating the 'Average GPA' column."
assert( math.isclose(df_year['Average GPA'].mean(), 3.3129267514166796) ), "Your calculation of the Average GPA by Year is incorrect."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.3: Visualizing GPA over Time
# We now have the data of the `Average GPA` across the University over time in years. Using this data, we can generate yet another visualization built-in to Pandas to visualize this data: a **line plot**!
#
# You can plot a **connected line** that draws your **numeric data** from a DataFrame, `df`, using the syntax:
#
# &emsp;`df.plot.line(x='column1', y='column2')`
#
# This line of code plots the line and specifies the **column names** to be used for the **x-values** and **y-values** of the points on your line plot.
#
#
# In the cell below, using similar syntax, plot the **average GPA over time** using `df_year`.
#
# *Hint: the `Year` column should provide **x-values** and the `Average GPA` column should provide **y-values**.*

# %%
df.plot.line(x ='Year', y='Average GPA')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ***Side Note***: If you're using **Visual Studio Code** on **dark mode**, you may not be able to see the **axes** and **axes labels** of the graph.
#
# **Only if** this is the case, please **copy and run** the following **two lines** of code in a cell:
#
# &emsp;`from matplotlib import style` <br>
# &emsp;`style.use('dark_background')`
#
# And then **re-run your plotting code** above.

# %% [markdown]
# ### Analysis: Plotted GPA over Time
#
# **Q5: Note a few observations you have about the changes to `Average GPA` at Illinois over time. Is there an overall trend? What events could have spiked increases to the Average GPA? Respond with at least three sentences.**

# %% [markdown]
# In 2020, there was a dramatic decrease in the average GPA. This could be because of the switch online due to COVID impacting student's ability to perform. However, from 2021 - 2022 the trendline stayed flat, showing that the Average GPA stayed stagnant, possibly also because students were adjusting to online learning. In 2014, there was a dramtic increase in the average GPA - possibly because of increased online resources available to students.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
